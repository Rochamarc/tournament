# %%
from controllers.championships_controller import ChampionshipsController

import pandas as pd

# %%
championships_controller = ChampionshipsController()

# %%
# Define a header for DataFrame columns

header = ['Clube','Partidas','Vitorias','Empates','Derrotas','Gols Marcados','Gols Sofridos','Saldo de Gols','Pontos']

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_a_22 = championships_controller.select_championship_table_by_division(2022, 'Serie A')
serie_a_23 = championships_controller.select_championship_table_by_division(2023, 'Serie A')
serie_a_24 = championships_controller.select_championship_table_by_division(2024, 'Serie A')
serie_a_25 = championships_controller.select_championship_table_by_division(2025, 'Serie A')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_a_22, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0               Flamengo        38        27        9         2
# 1             Fluminense        38        28        5         5
# 2              São Paulo        38        20        8        10
# 3          International        38        20        7        11
# 4                 Grêmio        38        18       12         8
# 5       Atlético Mineiro        38        19        6        13
# 6              Palmeiras        38        17       10        11
# 7            Corinthians        38        16       12        10
# 8    Atlético Goianiense        38        14        6        18
# 9   Athletico Paranaense        38        11       14        13
# 10   Red Bull Bragantino        38        13        7        18
# 11                 Ceará        38        10       13        15
# 12                Santos        38        10       12        16
# 13                 Bahia        38         9       15        14
# 14             Fortaleza        38        10       11        17
# 15           Chapecoense        38        10       10        18
# 16       América Mineiro        38         8       13        17
# 17                Cuiabá        38        10        6        22
# 18          Sport Recife        38         6       13        19
# 19             Juventude        38         6        7        25
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              88             71             17      90
# 1              74             75             -1      89
# 2              84             62             22      68
# 3              71             84            -13      67
# 4              69             69              0      66
# 5              84             69             15      63
# 6              70             58             12      61
# 7              65             46             19      60
# 8              62             68             -6      48
# 9              51             47              4      47
# 10             55             62             -7      46
# 11             51             51              0      43
# 12             48             54             -6      42
# 13             57             53              4      42
# 14             48             56             -8      41
# 15             50             59             -9      40
# 16             54             50              4      37
# 17             45             54             -9      36
# 18             47             38              9      31
# 19             49             56             -7      25

# %%
# Define dataframe from serie a 2023


pd.DataFrame(serie_a_23, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0             Fluminense        38        30        0         8
# 1          International        38        29        0         9
# 2       Atlético Mineiro        38        29        0         9
# 3              São Paulo        38        28        0        10
# 4            Corinthians        38        27        0        11
# 5               Flamengo        38        26        0        12
# 6                 Grêmio        38        25        0        13
# 7              Palmeiras        38        25        0        13
# 8               Coritiba        38        17        0        21
# 9    Atlético Goianiense        38        16        1        21
# 10  Athletico Paranaense        38        16        0        22
# 11                 Ceará        38        16        0        22
# 12             Fortaleza        38        16        0        22
# 13              Cruzeiro        38        15        0        23
# 14   Red Bull Bragantino        38        15        0        23
# 15                Santos        38        14        0        24
# 16                 Bahia        38        11        0        27
# 17              Botafogo        38        11        0        27
# 18             Confiança        38         8        0        30
# 19           Chapecoense        38         5        1        32
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0             131            140             -9      90
# 1             137            154            -17      87
# 2             127            147            -20      87
# 3             147            122             25      84
# 4             138            140             -2      81
# 5             144            130             14      78
# 6             127            145            -18      75
# 7             133            137             -4      75
# 8             137            148            -11      51
# 9             135            145            -10      49
# 10            152            125             27      48
# 11            132            143            -11      48
# 12            148            127             21      48
# 13            141            144             -3      45
# 14            130            141            -11      45
# 15            146            140              6      42
# 16            147            129             18      33
# 17            125            146            -21      33
# 18            124            135            -11      24
# 19            115            148            -33      16

# %%
pd.DataFrame(serie_a_24, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0          International        38        31        0         7
# 1            Corinthians        38        31        0         7
# 2                 Grêmio        38        27        0        11
# 3       Atlético Mineiro        38        26        0        12
# 4             Fluminense        38        25        0        13
# 5              Palmeiras        38        24        0        14
# 6              São Paulo        38        23        0        15
# 7               Flamengo        38        23        0        15
# 8    Atlético Goianiense        38        17        0        21
# 9              Fortaleza        38        17        0        21
# 10         Vasco da Gama        38        16        0        22
# 11                 Ceará        38        16        0        22
# 12       América Mineiro        38        16        0        22
# 13  Athletico Paranaense        38        15        0        23
# 14   Red Bull Bragantino        38        14        0        24
# 15              Coritiba        38        14        0        24
# 16                 Goiás        38        12        0        26
# 17                Santos        38        11        0        27
# 18              Cruzeiro        38        11        0        27
# 19                Cuiabá        38        11        0        27
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0             135            136             -1      93
# 1             143            141              2      93
# 2             131            146            -15      81
# 3             159            127             32      78
# 4             146            142              4      75
# 5             124            149            -25      72
# 6             146            129             17      69
# 7             150            136             14      69
# 8             148            136             12      51
# 9             159            126             33      51
# 10            144            139              5      48
# 11            155            143             12      48
# 12            148            124             24      48
# 13            132            144            -12      45
# 14            138            141             -3      42
# 15            150            126             24      42
# 16            129            147            -18      36
# 17            142            138              4      33
# 18            136            148            -12      33
# 19            141            138              3      33

# %%
pd.DataFrame(serie_a_25, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0                 Grêmio        38        29        0         9
# 1              Palmeiras        38        28        0        10
# 2       Atlético Mineiro        38        27        0        11
# 3          International        38        27        0        11
# 4             Fluminense        38        26        0        12
# 5              São Paulo        38        26        0        12
# 6            Corinthians        38        25        0        13
# 7               Flamengo        38        24        0        14
# 8                  Bahia        38        20        0        18
# 9    Red Bull Bragantino        38        19        0        19
# 10         Vasco da Gama        38        17        0        21
# 11              Coritiba        38        17        0        21
# 12  Athletico Paranaense        38        16        0        22
# 13                 Ceará        38        15        0        23
# 14              Botafogo        38        15        0        23
# 15             Fortaleza        38        14        0        24
# 16       América Mineiro        38        13        0        25
# 17               Vitória        38        10        0        28
# 18   Atlético Goianiense        38         7        0        31
# 19              Operário        38         5        0        33
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0             139            131              8      87
# 1             147            137             10      84
# 2             136            140             -4      81
# 3             143            142              1      81
# 4             155            129             26      78
# 5             133            143            -10      78
# 6             145            137              8      75
# 7             136            142             -6      72
# 8             134            135             -1      60
# 9             140            131              9      57
# 10            137            150            -13      51
# 11            137            150            -13      51
# 12            143            141              2      48
# 13            121            161            -40      45
# 14            146            138              8      45
# 15            146            138              8      42
# 16            158            132             26      39
# 17            152            122             30      30
# 18            125            143            -18      21
# 19            131            126              5      15

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_b_22 = championships_controller.select_championship_table_by_division(2022, 'Serie B')
serie_b_23 = championships_controller.select_championship_table_by_division(2023, 'Serie B')
serie_b_24 = championships_controller.select_championship_table_by_division(2024, 'Serie B')
serie_b_25 = championships_controller.select_championship_table_by_division(2025, 'Serie B')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_b_22, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0            Botafogo        38        16       18         4             36
# 1           Confiança        38        18       11         9             46
# 2            Coritiba        38        17       10        11             43
# 3            Cruzeiro        38        14       14        10             44
# 4               Goiás        38        14       14        10             41
# 5                 CSA        38        14       13        11             38
# 6             Guarani        38        14       11        13             45
# 7            Operário        38        13       11        14             40
# 8           Vila Nova        38        12       14        12             32
# 9             Vitória        38        12       13        13             35
# 10            Brusque        38         9       22         7             27
# 11           Londrina        38        10       17        11             44
# 12      Vasco da Gama        38        10       16        12             31
# 13               Remo        38        12       10        16             47
# 14  Brasil de Pelotas        38        12        8        18             39
# 15     Sampaio Corrêa        38         9       17        12             32
# 16                CRB        38         9       17        12             28
# 17            Náutico        38        11        9        18             44
# 18        Ponte Preta        38        10       11        17             36
# 19               Avaí        38         9       14        15             38
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              43             -7      66
# 1              37              9      65
# 2              49             -6      61
# 3              38              6      56
# 4              35              6      56
# 5              42             -4      55
# 6              33             12      53
# 7              32              8      50
# 8              28              4      50
# 9              23             12      49
# 10             32             -5      49
# 11             37              7      47
# 12             41            -10      46
# 13             28             19      46
# 14             43             -4      44
# 15             36             -4      44
# 16             47            -19      44
# 17             32             12      42
# 18             50            -14      41
# 19             28             10      41

# %%
# Define dataframe from serie a 2023

pd.DataFrame(serie_b_23, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0     América Mineiro        38        32        0         6            128
# 1       Vasco da Gama        38        32        0         6            139
# 2              Cuiabá        38        30        0         8            134
# 3               Goiás        38        24        0        14            130
# 4             Vitória        38        22        2        14            137
# 5           Juventude        38        21        1        16            151
# 6                 CSA        38        21        1        16            128
# 7            Operário        38        21        0        17            130
# 8           Vila Nova        38        19        3        16            136
# 9             Guarani        38        18        3        17            139
# 10           Londrina        38        19        0        19            146
# 11               Remo        38        17        2        19            130
# 12  Brasil de Pelotas        38        16        3        19            137
# 13            Brusque        38        15        4        19            131
# 14     Sampaio Corrêa        38        15        3        20            138
# 15       Sport Recife        38        14        3        21            126
# 16           Ypiranga        38         8        1        29            123
# 17             Manaus        38         7        3        28            122
# 18           São José        38         6        3        29            119
# 19        Botafogo-PB        38         5        4        29            120
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0             146            -18      96
# 1             120             19      96
# 2             142             -8      90
# 3             140            -10      72
# 4             128              9      68
# 5             123             28      64
# 6             130             -2      64
# 7             140            -10      63
# 8             137             -1      60
# 9             122             17      57
# 10            118             28      57
# 11            124              6      53
# 12            126             11      51
# 13            143            -12      49
# 14            121             17      48
# 15            139            -13      45
# 16            106             17      25
# 17            115              7      24
# 18            117              2      21
# 19            101             19      19

# %%
pd.DataFrame(serie_b_24, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0               Bahia        38        30        0         8            137
# 1            Botafogo        38        28        0        10            147
# 2            Operário        38        20        4        14            142
# 3             Vitória        38        21        0        17            138
# 4      Sampaio Corrêa        38        19        2        17            141
# 5             Brusque        38        18        2        18            154
# 6            Londrina        38        18        1        19            140
# 7        Sport Recife        38        17        4        17            137
# 8                 CSA        38        17        4        17            155
# 9           Vila Nova        38        17        3        18            140
# 10        Ponte Preta        38        17        2        19            151
# 11            Náutico        38        17        2        19            144
# 12          Confiança        38        17        1        20            155
# 13        Chapecoense        38        15        6        17            130
# 14               Avaí        38        16        3        19            152
# 15            Guarani        38        15        4        19            135
# 16               Remo        38        16        1        21            138
# 17          Juventude        38        13        7        18            151
# 18                CRB        38        13        5        20            141
# 19  Brasil de Pelotas        38         7        7        24            144
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0             139             -2      90
# 1             130             17      84
# 2             134              8      64
# 3             150            -12      63
# 4             132              9      59
# 5             128             26      56
# 6             131              9      55
# 7             134              3      55
# 8             121             34      55
# 9             135              5      54
# 10            125             26      53
# 11            134             10      53
# 12            139             16      52
# 13            149            -19      51
# 14            134             18      51
# 15            142             -7      49
# 16            127             11      49
# 17            137             14      46
# 18            139              2      44
# 19            134             10      28

# %%
pd.DataFrame(serie_b_25, columns=header)
# Out:
#              Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0           Santos        38        32        0         6            126
# 1            Goiás        38        29        1         8            136
# 2           Cuiabá        38        29        0         9            136
# 3         Cruzeiro        38        28        1         9            131
# 4         Londrina        38        25        0        13            131
# 5              CSA        38        21        3        14            143
# 6          Guarani        38        19        3        16            141
# 7             Avaí        38        19        2        17            145
# 8      Chapecoense        38        18        3        17            131
# 9        Vila Nova        38        19        0        19            132
# 10         Náutico        38        18        1        19            157
# 11     Ponte Preta        38        16        2        20            139
# 12    Sport Recife        38        15        3        20            146
# 13  Sampaio Corrêa        38        15        3        20            143
# 14       Confiança        38        15        2        21            141
# 15         Brusque        38        14        4        20            151
# 16   Novorizontino        38        11        2        25            120
# 17        Ypiranga        38         8        2        28            124
# 18           Altos        38         5        5        28            111
# 19         Mirasol        38         5        1        32            118
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0             134             -8      96
# 1             132              4      88
# 2             126             10      87
# 3             139             -8      85
# 4             139             -8      75
# 5             134              9      66
# 6             126             15      60
# 7             118             27      59
# 8             120             11      57
# 9             126              6      57
# 10            121             36      55
# 11            134              5      50
# 12            132             14      48
# 13            119             24      48
# 14            107             34      47
# 15            113             38      46
# 16            118              2      35
# 17            114             10      26
# 18            119             -8      20
# 19            109              9      16

# %%
# Serie C

serie_c_22 = championships_controller.select_championship_table_by_division(2022, 'Serie C')
serie_c_23 = championships_controller.select_championship_table_by_division(2023, 'Serie C')
serie_c_24 = championships_controller.select_championship_table_by_division(2024, 'Serie C')
serie_c_25 = championships_controller.select_championship_table_by_division(2025, 'Serie C')

# %%
pd.DataFrame(serie_c_22, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0          Manaus        38        14       15         9             16
# 1        Ypiranga        38        12       20         6             13
# 2     Botafogo-PB        38        12       19         7             16
# 3        São José        38        14       13        11             22
# 4     Botafogo SP        38        11       21         6             16
# 5     Figueirense        38        12       18         8             23
# 6         Mirasol        38        12       17         9             18
# 7   Novorizontino        38        11       20         7             16
# 8           Oeste        38        10       18        10             25
# 9      Jacuipense        38         8       24         6             13
# 10     Santa Cruz        38         9       20         9             20
# 11       Tombense        38         9       20         9             19
# 12       Paysandu        38         8       20        10             18
# 13       Floresta        38         9       16        13             23
# 14          Altos        38         7       22         9             10
# 15         Ituano        38         7       20        11             22
# 16         Paraná        38         8       17        13             17
# 17    Ferroviário        38         5       21        12             18
# 18  Volta Redonda        38         4       24        10             14
# 19       Criciúma        38         3       25        10             11
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              16              0      57
# 1              19             -6      56
# 2              16              0      55
# 3              16              6      55
# 4              14              2      54
# 5              20              3      54
# 6              12              6      53
# 7              16              0      53
# 8              14             11      48
# 9              12              1      48
# 10             14              6      47
# 11             12              7      47
# 12             11              7      44
# 13             16              7      43
# 14             22            -12      43
# 15             14              8      41
# 16             17              0      41
# 17             20             -2      36
# 18             11              3      36
# 19             16             -5      34

# %%
pd.DataFrame(serie_c_23, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0     Ponte Preta        38        31        3         4            137
# 1         Náutico        38        28        1         9            128
# 2             CRB        38        25        5         8            136
# 3            Avaí        38        23        5        10            113
# 4      Jacuipense        38        19        6        13            113
# 5     Ferroviário        38        19        3        16            104
# 6        Floresta        38        18        3        17            119
# 7     Figueirense        38        16        5        17            101
# 8         Mirasol        38        16        3        19            111
# 9           Oeste        38        16        3        19            104
# 10  Volta Redonda        38        15        4        19            106
# 11       Paysandu        38        14        6        18             83
# 12          Altos        38        15        3        20            105
# 13  Novorizontino        38        14        5        19             88
# 14       Criciúma        38        13        6        19            107
# 15     Santa Cruz        38        14        2        22            100
# 16         Ituano        38        13        4        21            104
# 17       Tombense        38        12        3        23            108
# 18         Paraná        38        12        2        24            100
# 19    Botafogo SP        38         9        4        25            105
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0             117             20      96
# 1             113             15      85
# 2             108             28      80
# 3             127            -14      74
# 4              89             24      63
# 5              95              9      60
# 6              88             31      57
# 7             117            -16      53
# 8             110              1      51
# 9             100              4      51
# 10            113             -7      49
# 11            102            -19      48
# 12            100              5      48
# 13            108            -20      47
# 14            100              7      45
# 15             91              9      44
# 16            100              4      43
# 17            107              1      39
# 18            112            -12      38
# 19            119            -14      31

# %%
pd.DataFrame(serie_c_24, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0        Ypiranga        38        21        6        11            101
# 1   Novorizontino        38        20        8        10            105
# 2           Altos        38        21        2        15            125
# 3         Mirasol        38        19        8        11            100
# 4     Botafogo-PB        38        18        4        16             89
# 5      Santa Cruz        38        16        8        14            106
# 6   Volta Redonda        38        17        5        16            114
# 7     Ferroviário        38        16        7        15             98
# 8        Tombense        38        17        3        18             97
# 9           Oeste        38        16        6        16            117
# 10         Paraná        38        16        5        17            101
# 11    Figueirense        38        15        6        17             95
# 12       Floresta        38        14        9        15             90
# 13     Jacuipense        38        15        5        18            109
# 14       Paysandu        38        15        4        19            119
# 15       Criciúma        38        15        4        19             94
# 16         Ituano        38        14        7        17             95
# 17         Manaus        38        14        6        18            100
# 18       São José        38        12        7        19            105
# 19    Botafogo SP        38        10        8        20             92
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              85             16      69
# 1             101              4      68
# 2              96             29      65
# 3             105             -5      65
# 4              93             -4      58
# 5             102              4      56
# 6              97             17      56
# 7              97              1      55
# 8             101             -4      54
# 9              90             27      54
# 10             98              3      53
# 11            104             -9      51
# 12            109            -19      51
# 13             93             16      50
# 14             92             27      49
# 15             86              8      49
# 16             93              2      49
# 17            100              0      48
# 18            102              3      43
# 19             84              8      38

# %%
pd.DataFrame(serie_c_25, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0                 CRB        38        31        2         5            129
# 1           Juventude        38        30        3         5            120
# 2                Remo        38        30        3         5            114
# 3   Brasil de Pelotas        38        26        6         6            124
# 4            Tombense        38        18        5        15            119
# 5              Manaus        38        17        4        17            103
# 6         Botafogo-PB        38        16        4        18            113
# 7            São José        38        14        9        15            110
# 8            Paysandu        38        15        5        18            117
# 9          Jacuipense        38        15        5        18            118
# 10           Floresta        38        15        5        18            105
# 11           Criciúma        38        15        4        19            106
# 12             Paraná        38        13        8        17             93
# 13        Ferroviário        38        11        8        19            104
# 14      Volta Redonda        38        11        7        20             94
# 15              Oeste        38        10        9        19            106
# 16        Figueirense        38        10        6        22             92
# 17             Ituano        38        12        0        26            109
# 18        Botafogo SP        38        10        6        22             92
# 19         Santa Cruz        38         9        5        24            104
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0             130             -1      95
# 1             119              1      93
# 2             120             -6      93
# 3             115              9      84
# 4             107             12      59
# 5             100              3      55
# 6              90             23      52
# 7              82             28      51
# 8             101             16      50
# 9              93             25      50
# 10            106             -1      50
# 11             98              8      49
# 12             91              2      47
# 13             99              5      41
# 14            103             -9      40
# 15            105              1      39
# 16             84              8      36
# 17             92             17      36
# 18            122            -30      36
# 19            101              3      32

# %%
"""
Analisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores
e manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados

Regulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados
pois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade
as divisoes possuem um peso de excelencia

Passo 1
Atribuir um padrão de criação de dados para jogadores de times grandes e pequenos,
baseados na divisão que eles jogam.
Para isso o confifgure devera puxar os clubes por divisão
e o data generation nao deve criar dados da maneira atual

ex:
configure -> criar jogadores skills por divisão
data_manipulation -> criar dados baseados num peso
"""
# Out:
# "\nAnalisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores\ne manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados\n\nRegulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados\npois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade\nas divisoes possuem um peso de excelencia\n\nPasso 1\nAtribuir um padrão de criação de dados para jogadores de times grandes e pequenos,\nbaseados na divisão que eles jogam.\nPara isso o confifgure devera puxar os clubes por divisão\ne o data generation nao deve criar dados da maneira atual\n\nex:\nconfigure -> criar jogadores skills por divisão\ndata_manipulation -> criar dados baseados num peso\n"

# %%
# 19 dez 2023

"""
Analisando os resultados, conclui-se que:
Time da serie B e da serie C são potencialmente capazes de ganhar a serie A e/ou as series seguintes, como o floresta 
que foi campeao seguida da C, B e depois da A.

O lógico é que essas divisões possuem um nível técnico mais baixo, onde a lógica, se estabeleça de que quando um time caia,
ele tenha mais capacidade de sumir do seguir descendo como ocorreu o são paulo por exemplo, e times da serie B que subam pra A mesmo que possuem um nivel
técnico elevado com relação ao "teto técnico" da serie B não é o suficiente na serie A para que ele já seja capaz de conseguir ganhar a divisão.

Mudanças:
    Atribuir pesos a criação dos jogadores, essa regra de negocio pode ser aplicada dentro da aplicação e não no banco de dados
    Players.skills -> peso_baseado_no_clube

    Isso contando no overall total, porém esses valores podem ser distribuidos nas habilidades já que o que conta em si é a habilidade que 
    está sendo requerida e não o overall como um todo.
    
    A -> Jogadores de 55 a 80
    B -> Jogadores de 55 a 70
    C -> Jogadores de 55 a 65

    As médias de gols marcados é muito baixa, a de gols sofridos parace estar numa média boa, e as divisões também deveriam ter 
    diferenças com relação a quantidade de gols marcados e sofridos, porém essas mudanças talvez já possam ser observadas com as mudanças 
    das skills dos jogadores.
"""
# Out:
# '\nAnalisando os resultados, conclui-se que:\nTime da serie B e da serie C são potencialmente capazes de ganhar a serie A e/ou as series seguintes, como o floresta \nque foi campeao seguida da C, B e depois da A.\n\nO lógico é que essas divisões possuem um nível técnico mais baixo, onde a lógica, se estabeleça de que quando um time caia,\nele tenha mais capacidade de sumir do seguir descendo como ocorreu o são paulo por exemplo, e times da serie B que subam pra A mesmo que possuem um nivel\ntécnico elevado com relação ao "teto técnico" da serie B não é o suficiente na serie A para que ele já seja capaz de conseguir ganhar a divisão.\n\nMudanças:\n    Atribuir pesos a criação dos jogadores, essa regra de negocio pode ser aplicada dentro da aplicação e não no banco de dados\n    Players.skills -> peso_baseado_no_clube\n\n    Isso contando no overall total, porém esses valores podem ser distribuidos nas habilidades já que o que conta em si é a habilidade que \n    está sendo requerida e não o overall como um todo.\n    \n    A -> Jogadores de 55 a 80\n    B -> Jogadores de 55 a 70\n    C -> Jogadores de 55 a 65\n\n    As médias de gols marcados é muito baixa, a de gols sofridos parace estar numa média boa, e as divisões também deveriam ter \n    diferenças com relação a quantidade de gols marcados e sofridos, porém essas mudanças talvez já possam ser observadas com as mudanças \n    das skills dos jogadores.\n'
