# %%
from db.championships_controller import ChampionshipsController

import pandas as pd

# %%
championships_controller = ChampionshipsController()

# %%
# Define a header for DataFrame columns

header = ['Clube','Partidas','Vitorias','Empates','Derrotas','Gols Marcados','Gols Sofridos','Saldo de Gols','Pontos']

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_a_22 = championships_controller.select_championship_table_by_division(2022, 'Serie A')
serie_a_23 = championships_controller.select_championship_table_by_division(2023, 'Serie A')
serie_a_24 = championships_controller.select_championship_table_by_division(2024, 'Serie A')
serie_a_25 = championships_controller.select_championship_table_by_division(2025, 'Serie A')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_a_22, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0       Atlético Mineiro        38        18       13         7
# 1                 Santos        38        17       15         6
# 2                  Ceará        38        15       16         7
# 3        América Mineiro        38        14       16         8
# 4                  Bahia        38        16       10        12
# 5    Atlético Goianiense        38        15       11        12
# 6            Chapecoense        38        16        8        14
# 7             Fluminense        38        14       12        12
# 8          International        38        14       11        13
# 9           Sport Recife        38        12       13        13
# 10  Athletico Paranaense        38        10       19         9
# 11                Cuiabá        38        10       18        10
# 12                Grêmio        38        11       15        12
# 13             Fortaleza        38        12       12        14
# 14   Red Bull Bragantino        38        11       14        13
# 15           Corinthians        38         7       20        11
# 16             Palmeiras        38         8       15        15
# 17             Juventude        38         6       16        16
# 18              Flamengo        38         6       16        16
# 19             São Paulo        38         4       18        16
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              23             22              1      67
# 1              30             28              2      66
# 2              27             24              3      61
# 3              21             35            -14      58
# 4              41             30             11      58
# 5              23             26             -3      56
# 6              32             25              7      56
# 7              34             33              1      54
# 8              27             31             -4      53
# 9              30             26              4      49
# 10             21             14              7      49
# 11             23             20              3      48
# 12             33             29              4      48
# 13             22             32            -10      48
# 14             32             37             -5      47
# 15             31             14             17      41
# 16             33             36             -3      39
# 17             33             26              7      34
# 18             29             22              7      34
# 19             29             16             13      30

# %%
# Define dataframe from serie a 2023


pd.DataFrame(serie_a_23, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0          Vasco da Gama        38        19       14         5
# 1       Atlético Mineiro        38        16       19         3
# 2          International        38        15       14         9
# 3                Náutico        38        15       12        11
# 4                   Avaí        38        13       18         7
# 5                Vitória        38        16        8        14
# 6                 Santos        38        13       16         9
# 7        América Mineiro        38        14       13        11
# 8                 Cuiabá        38        12       17         9
# 9             Fluminense        38        13       12        13
# 10                 Ceará        38        11       18         9
# 11                 Bahia        38        11       14        13
# 12           Chapecoense        38         9       15        14
# 13  Athletico Paranaense        38         7       19        12
# 14   Atlético Goianiense        38         8       16        14
# 15          Sport Recife        38         8       15        15
# 16           Corinthians        38         7       18        13
# 17                Grêmio        38         7       17        14
# 18   Red Bull Bragantino        38         8       13        17
# 19             Fortaleza        38         7       14        17
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              39             39              0      71
# 1              19             22             -3      67
# 2              23             29             -6      59
# 3              33             19             14      57
# 4              18             25             -7      57
# 5              41             35              6      56
# 6              20             33            -13      55
# 7              31             25              6      55
# 8              22             31             -9      53
# 9              28             35             -7      51
# 10             21             27             -6      51
# 11             30             35             -5      47
# 12             25             23              2      42
# 13             17             19             -2      40
# 14             21             14              7      40
# 15             26             29             -3      39
# 16             18             22             -4      39
# 17             21             23             -2      38
# 18             25             40            -15      37
# 19             24             23              1      35

# %%
pd.DataFrame(serie_a_24, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0               Floresta        38        19       12         7
# 1       Atlético Mineiro        38        16       15         7
# 2                  Goiás        38        16       15         7
# 3                   Avaí        38        15       16         7
# 4            Ferroviário        38        14       19         5
# 5              Palmeiras        38        17        6        15
# 6   Athletico Paranaense        38        13       17         8
# 7                Náutico        38        13       15        10
# 8            Chapecoense        38        12       16        10
# 9        América Mineiro        38        13       12        13
# 10          Sport Recife        38        13       12        13
# 11         Vasco da Gama        38        12       14        12
# 12                 Ceará        38        11       15        12
# 13               Vitória        38        11       13        14
# 14            Fluminense        38        11       10        17
# 15         International        38        11       10        17
# 16   Atlético Goianiense        38         9       13        16
# 17                 Bahia        38         7       17        14
# 18                Santos        38         6       15        17
# 19                Cuiabá        38         4       12        22
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              38             28             10      69
# 1              29             23              6      63
# 2              30             32             -2      63
# 3              21             14              7      61
# 4              24             27             -3      61
# 5              41             42             -1      57
# 6              20             25             -5      56
# 7              26             27             -1      54
# 8              23             15              8      52
# 9              25             23              2      51
# 10             28             28              0      51
# 11             21             22             -1      50
# 12             23             16              7      48
# 13             43             44             -1      46
# 14             28             39            -11      43
# 15             41             26             15      43
# 16             20             20              0      40
# 17             31             32             -1      38
# 18             30             29              1      33
# 19             32             32              0      24

# %%
pd.DataFrame(serie_a_25, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0               Floresta        38        15       16         7
# 1               Flamengo        38        15       14         9
# 2          Vasco da Gama        38        16       10        12
# 3                   Avaí        38        14       14        10
# 4              Vila Nova        38        14       14        10
# 5                  Goiás        38        14       13        11
# 6      Brasil de Pelotas        38        14       13        11
# 7       Atlético Mineiro        38        12       17         9
# 8          International        38        12       17         9
# 9                Náutico        38        12       16        10
# 10               Vitória        38        14        8        16
# 11          Sport Recife        38        11       15        12
# 12             Palmeiras        38        11       14        13
# 13           Ferroviário        38        12       11        15
# 14  Athletico Paranaense        38         8       21         9
# 15           Chapecoense        38        10       14        14
# 16                 Ceará        38         9       16        13
# 17       América Mineiro        38         9       14        15
# 18            Fluminense        38         7       17        14
# 19                   CRB        38         6       16        16
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              31             20             11      61
# 1              34             26              8      59
# 2              29             28              1      58
# 3              24             23              1      56
# 4              25             24              1      56
# 5              29             26              3      55
# 6              28             27              1      55
# 7              21             18              3      53
# 8              31             25              6      53
# 9              35             20             15      52
# 10             41             26             15      50
# 11             31             19             12      48
# 12             28             25              3      47
# 13             30             22              8      47
# 14             31             11             20      45
# 15             25             25              0      44
# 16             23             25             -2      43
# 17             27             30             -3      41
# 18             34             28              6      38
# 19             33             22             11      34

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_b_22 = championships_controller.select_championship_table_by_division(2022, 'Serie B')
serie_b_23 = championships_controller.select_championship_table_by_division(2023, 'Serie B')
serie_b_24 = championships_controller.select_championship_table_by_division(2024, 'Serie B')
serie_b_25 = championships_controller.select_championship_table_by_division(2025, 'Serie B')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_b_22, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0             Vitória        38        20       10         8             43
# 1                Avaí        38        17       15         6             22
# 2       Vasco da Gama        38        16       16         6             17
# 3             Náutico        38        17       13         8             21
# 4      Sampaio Corrêa        38        15       15         8             21
# 5               Goiás        38        14       15         9             30
# 6                 CRB        38        14       15         9             37
# 7                 CSA        38        11       18         9             31
# 8           Vila Nova        38        11       18         9             25
# 9             Brusque        38        13        9        16             27
# 10           Londrina        38        10       16        12             29
# 11               Remo        38         9       19        10             25
# 12           Cruzeiro        38         9       18        11             22
# 13           Operário        38        10       13        15             31
# 14          Confiança        38        10       13        15             33
# 15  Brasil de Pelotas        38         9       15        14             29
# 16           Coritiba        38         8       17        13             30
# 17        Ponte Preta        38         8       15        15             43
# 18           Botafogo        38         6       12        20             29
# 19            Guarani        38         5       14        19             29
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              33             10      70
# 1              23             -1      66
# 2              22             -5      64
# 3              24             -3      64
# 4              16              5      60
# 5              26              4      57
# 6              24             13      57
# 7              22              9      51
# 8              30             -5      51
# 9              30             -3      48
# 10             24              5      46
# 11             21              4      46
# 12             26             -4      45
# 13             29              2      43
# 14             31              2      43
# 15             37             -8      42
# 16             24              6      41
# 17             26             17      39
# 18             26              3      30
# 19             24              5      29

# %%
# Define dataframe from serie a 2023

pd.DataFrame(serie_b_23, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0            Floresta        38        21       11         6             44
# 1           Palmeiras        38        19       13         6             31
# 2         Ferroviário        38        19       13         6             39
# 3               Goiás        38        18       12         8             27
# 4                 CRB        38        18       11         9             30
# 5           Vila Nova        38        18        9        11             32
# 6   Brasil de Pelotas        38        16        9        13             29
# 7            Flamengo        38        12       15        11             25
# 8      Sampaio Corrêa        38        10       18        10             24
# 9            Londrina        38        11       14        13             31
# 10           Paysandu        38        12        9        17             37
# 11          São Paulo        38        11       12        15             33
# 12           Cruzeiro        38         9       17        12             36
# 13           Operário        38         9       14        15             38
# 14                CSA        38         8       17        13             24
# 15          Confiança        38         8       16        14             28
# 16            Brusque        38         8       15        15             29
# 17          Juventude        38         7       15        16             28
# 18               Remo        38         5       17        16             22
# 19             Ituano        38         4       17        17             33
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              27             17      74
# 1              34             -3      70
# 2              31              8      70
# 3              33             -6      66
# 4              30              0      65
# 5              30              2      63
# 6              37             -8      57
# 7              33             -8      51
# 8              15              9      48
# 9              21             10      47
# 10             31              6      45
# 11             17             16      45
# 12             23             13      44
# 13             25             13      41
# 14             19              5      41
# 15             23              5      40
# 16             23              6      39
# 17             29             -1      36
# 18             30             -8      32
# 19             27              6      29

# %%
pd.DataFrame(serie_b_24, columns=header)
# Out:
#                   Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0                   CRB        38        21       11         6             34
# 1     Brasil de Pelotas        38        19       11         8             33
# 2             Vila Nova        38        18       13         7             32
# 3              Flamengo        38        16       13         9             32
# 4           Corinthians        38        15       16         7             29
# 5           Figueirense        38        13       17         8             33
# 6              Tombense        38        15        9        14             35
# 7        Sampaio Corrêa        38        14       12        12             26
# 8           Botafogo-PB        38        12       14        12             34
# 9              Paysandu        38        12       12        14             31
# 10                  CSA        38        10       16        12             33
# 11            São Paulo        38        10       15        13             21
# 12             Cruzeiro        38        10       15        13             23
# 13  Red Bull Bragantino        38        10       14        14             49
# 14             Londrina        38        10       12        16             36
# 15               Manaus        38         9       14        15             37
# 16               Grêmio        38         7       18        13             29
# 17             Operário        38         7       16        15             31
# 18            Fortaleza        38         7       16        15             30
# 19            Confiança        38         4       18        16             26
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              31              3      74
# 1              35             -2      68
# 2              36             -4      67
# 3              36             -4      61
# 4              27              2      61
# 5              27              6      56
# 6              39             -4      54
# 7              31             -5      54
# 8              30              4      50
# 9              41            -10      48
# 10             34             -1      46
# 11             24             -3      45
# 12             28             -5      45
# 13             37             12      44
# 14             34              2      42
# 15             40             -3      41
# 16             20              9      39
# 17             34             -3      37
# 18             34             -4      37
# 19             22              4      30

# %%
pd.DataFrame(serie_b_25, columns=header)
# Out:
#                   Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0           Botafogo-PB        38        19       10         9             34
# 1              Londrina        38        18        9        11             45
# 2   Atlético Goianiense        38        16       14         8             28
# 3              Cruzeiro        38        16       13         9             23
# 4                 Oeste        38        16       10        12             24
# 5        Sampaio Corrêa        38        15       11        12             31
# 6                 Bahia        38        13       14        11             38
# 7              Tombense        38        14       11        13             30
# 8                   CSA        38        13       12        13             41
# 9              Paysandu        38        13       11        14             39
# 10  Red Bull Bragantino        38        13       11        14             38
# 11          Figueirense        38        12       12        14             41
# 12          Corinthians        38        11       15        12             26
# 13                Altos        38        11       15        12             33
# 14           Jacuipense        38        13        9        16             39
# 15            São Paulo        38        12       10        16             26
# 16        Volta Redonda        38        10       14        14             31
# 17               Cuiabá        38         9       14        15             29
# 18               Santos        38         7       18        13             17
# 19               Manaus        38         5       15        18             31
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              31              3      67
# 1              42              3      63
# 2              20              8      62
# 3              31             -8      61
# 4              31             -7      58
# 5              26              5      56
# 6              24             14      53
# 7              20             10      53
# 8              27             14      51
# 9              31              8      50
# 10             47             -9      50
# 11             27             14      48
# 12             25              1      48
# 13             26              7      48
# 14             29             10      48
# 15             25              1      46
# 16             35             -4      44
# 17             23              6      41
# 18             37            -20      39
# 19             43            -12      30

# %%
# Serie C

serie_c_22 = championships_controller.select_championship_table_by_division(2022, 'Serie C')
serie_c_23 = championships_controller.select_championship_table_by_division(2023, 'Serie C')
serie_c_24 = championships_controller.select_championship_table_by_division(2024, 'Serie C')
serie_c_25 = championships_controller.select_championship_table_by_division(2025, 'Serie C')

# %%
pd.DataFrame(serie_c_22, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0        Floresta        38        23       11         4             39
# 1     Ferroviário        38        18       16         4             33
# 2          Ituano        38        17        9        12             32
# 3        Paysandu        38        15       14         9             25
# 4        São José        38        15       12        11             34
# 5     Botafogo-PB        38        14       14        10             34
# 6          Paraná        38        15       11        12             42
# 7        Tombense        38        14       13        11             34
# 8      Jacuipense        38        14       13        11             42
# 9           Oeste        38        13       10        15             38
# 10         Manaus        38        13       10        15             55
# 11  Volta Redonda        38        12       12        14             24
# 12    Figueirense        38        13        7        18             53
# 13  Novorizontino        38        11       12        15             28
# 14     Santa Cruz        38        11       12        15             24
# 15       Ypiranga        38        10       15        13             28
# 16        Mirasol        38         6       20        12             27
# 17       Criciúma        38         5       21        12             22
# 18          Altos        38         8       10        20             42
# 19    Botafogo SP        38         6       12        20             32
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              40             -1      80
# 1              32              1      70
# 2              29              3      60
# 3              18              7      59
# 4              25              9      57
# 5              28              6      56
# 6              35              7      56
# 7              22             12      55
# 8              30             12      55
# 9              32              6      49
# 10             43             12      49
# 11             30             -6      48
# 12             43             10      46
# 13             46            -18      45
# 14             30             -6      45
# 15             20              8      45
# 16             28             -1      38
# 17             19              3      36
# 18             38              4      34
# 19             34             -2      30

# %%
pd.DataFrame(serie_c_23, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0          Manaus        38        18       13         7             49
# 1     Botafogo-PB        38        16       18         4             25
# 2     Figueirense        38        17       14         7             27
# 3        Tombense        38        16       15         7             29
# 4           Oeste        38        16       13         9             30
# 5      Santa Cruz        38        15       13        10             30
# 6     Ponte Preta        38        16        8        14             44
# 7        Ypiranga        38        15       11        12             23
# 8        São José        38        14       13        11             23
# 9   Volta Redonda        38        12       16        10             44
# 10          Altos        38        13       13        12             40
# 11     Jacuipense        38        12       15        11             30
# 12       Criciúma        38        13       12        13             27
# 13    Botafogo SP        38        13       12        13             26
# 14         Paraná        38        11       12        15             36
# 15  Novorizontino        38         9       14        15             33
# 16       Botafogo        38         8       11        19             36
# 17        Mirasol        38         4       17        17             21
# 18        Guarani        38         6       10        22             34
# 19       Coritiba        38         6       10        22             23
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              41              8      67
# 1              28             -3      66
# 2              37            -10      65
# 3              30             -1      63
# 4              27              3      61
# 5              26              4      58
# 6              34             10      56
# 7              28             -5      56
# 8              29             -6      55
# 9              24             20      52
# 10             25             15      52
# 11             30              0      51
# 12             20              7      51
# 13             30             -4      51
# 14             36              0      45
# 15             36             -3      41
# 16             30              6      35
# 17             25             -4      29
# 18             31              3      28
# 19             19              4      28

# %%
pd.DataFrame(serie_c_24, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0           Altos        38        20        7        11             41
# 1           Oeste        38        16       16         6             25
# 2   Volta Redonda        38        17       10        11             29
# 3      Jacuipense        38        16       12        10             33
# 4       Juventude        38        15       14         9             38
# 5        São José        38        15       14         9             30
# 6   Novorizontino        38        13       16         9             34
# 7        Ypiranga        38        14       12        12             24
# 8            Remo        38        12       16        10             25
# 9      Santa Cruz        38        12       15        11             23
# 10    Ponte Preta        38        11       14        13             36
# 11         Paraná        38        10       17        11             28
# 12        Guarani        38         9       18        11             28
# 13         Ituano        38        10       14        14             26
# 14    Botafogo SP        38         9       16        13             35
# 15       Coritiba        38         9       13        16             29
# 16       Botafogo        38         9       12        17             26
# 17       Criciúma        38         6       19        13             16
# 18        Mirasol        38         7       16        15             17
# 19        Brusque        38         3       23        12             19
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              31             10      67
# 1              24              1      64
# 2              29              0      61
# 3              36             -3      60
# 4              29              9      59
# 5              33             -3      59
# 6              31              3      55
# 7              25             -1      54
# 8              19              6      52
# 9              40            -17      51
# 10             30              6      47
# 11             30             -2      47
# 12             32             -4      45
# 13             30             -4      44
# 14             25             10      43
# 15             31             -2      40
# 16             27             -1      39
# 17             19             -3      37
# 18             22             -5      37
# 19             19              0      32

# %%
pd.DataFrame(serie_c_25, columns=header)
# Out:
#             Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0            Remo        38        18       10        10             39
# 1     Ponte Preta        38        15       15         8             35
# 2        São José        38        16       10        12             25
# 3         Guarani        38        15       13        10             34
# 4        Coritiba        38        15       12        11             30
# 5        Botafogo        38        16        8        14             42
# 6          Ituano        38        15       10        13             44
# 7       Juventude        38        13       15        10             31
# 8        Ypiranga        38        14       12        12             27
# 9     Botafogo SP        38        13       12        13             37
# 10         Grêmio        38        13       11        14             26
# 11        Brusque        38        12       13        13             28
# 12       Operário        38        12       13        13             30
# 13       Criciúma        38        12       11        15             26
# 14      Confiança        38        11       13        14             39
# 15     Santa Cruz        38        11       12        15             34
# 16         Paraná        38        10       14        14             33
# 17  Novorizontino        38         9       16        13             33
# 18      Fortaleza        38         8       14        16             25
# 19        Mirasol        38         4       22        12             14
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              37              2      64
# 1              30              5      60
# 2              30             -5      58
# 3              26              8      58
# 4              34             -4      57
# 5              45             -3      56
# 6              25             19      55
# 7              24              7      54
# 8              23              4      54
# 9              31              6      51
# 10             29             -3      50
# 11             28              0      49
# 12             34             -4      49
# 13             31             -5      47
# 14             33              6      46
# 15             20             14      45
# 16             37             -4      44
# 17             26              7      43
# 18             26             -1      38
# 19             19             -5      34

# %%
"""
Analisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores
e manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados

Regulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados
pois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade
as divisoes possuem um peso de excelencia

Passo 1
Atribuir um padrão de criação de dados para jogadores de times grandes e pequenos,
baseados na divisão que eles jogam.
Para isso o confifgure devera puxar os clubes por divisão
e o data generation nao deve criar dados da maneira atual

ex:
configure -> criar jogadores skills por divisão
data_manipulation -> criar dados baseados num peso
"""
# Out:
# "\nAnalisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores\ne manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados\n\nRegulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados\npois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade\nas divisoes possuem um peso de excelencia\n\nPasso 1\nAtribuir um padrão de criação de dados para jogadores de times grandes e pequenos,\nbaseados na divisão que eles jogam.\nPara isso o confifgure devera puxar os clubes por divisão\ne o data generation nao deve criar dados da maneira atual\n\nex:\nconfigure -> criar jogadores skills por divisão\ndata_manipulation -> criar dados baseados num peso\n"

# %%
# 19 dez 2023

"""
Analisando os resultados, conclui-se que:
Time da serie B e da serie C são potencialmente capazes de ganhar a serie A e/ou as series seguintes, como o floresta 
que foi campeao seguida da C, B e depois da A.

O lógico é que essas divisões possuem um nível técnico mais baixo, onde a lógica, se estabeleça de que quando um time caia,
ele tenha mais capacidade de sumir do seguir descendo como ocorreu o são paulo por exemplo, e times da serie B que subam pra A mesmo que possuem um nivel
técnico elevado com relação ao "teto técnico" da serie B não é o suficiente na serie A para que ele já seja capaz de conseguir ganhar a divisão.

Mudanças:
    Atribuir pesos a criação dos jogadores, essa regra de negocio pode ser aplicada dentro da aplicação e não no banco de dados
    Players.skills -> peso_baseado_no_clube

    Isso contando no overall total, porém esses valores podem ser distribuidos nas habilidades já que o que conta em si é a habilidade que 
    está sendo requerida e não o overall como um todo.
    
    A -> Jogadores de 55 a 80
    B -> Jogadores de 55 a 70
    C -> Jogadores de 55 a 65

    As médias de gols marcados é muito baixa, a de gols sofridos parace estar numa média boa, e as divisões também deveriam ter 
    diferenças com relação a quantidade de gols marcados e sofridos, porém essas mudanças talvez já possam ser observadas com as mudanças 
    das skills dos jogadores.
"""
# Out:
# '\nAnalisando os resultados, conclui-se que:\nTime da serie B e da serie C são potencialmente capazes de ganhar a serie A e/ou as series seguintes, como o floresta \nque foi campeao seguida da C, B e depois da A.\n\nO lógico é que essas divisões possuem um nível técnico mais baixo, onde a lógica, se estabeleça de que quando um time caia,\nele tenha mais capacidade de sumir do seguir descendo como ocorreu o são paulo por exemplo, e times da serie B que subam pra A mesmo que possuem um nivel\ntécnico elevado com relação ao "teto técnico" da serie B não é o suficiente na serie A para que ele já seja capaz de conseguir ganhar a divisão.\n\nMudanças:\n    Atribuir pesos a criação dos jogadores, essa regra de negocio pode ser aplicada dentro da aplicação e não no banco de dados\n    Players.skills -> peso_baseado_no_clube\n\n    As médias de gols marcados é muito baixa, a de gols sofridos parace estar numa média boa, e as divisões também deveriam ter \n    diferenças com relação a quantidade de gols marcados e sofridos, porém essas mudanças talvez já possam ser observadas com as mudanças \n    das skills dos jogadores\n'
