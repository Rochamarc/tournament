# %%
from db.championship_controller import ChampionshipsController

import pandas as pd

# %%
championships_controller = ChampionshipsController()

# %%
# Define a header for DataFrame columns

header = ['Clube','Partidas','Vitorias','Empates','Derrotas','Gols Marcados','Gols Sofridos','Saldo de Gols','Pontos']

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_a_22 = championships_controller.select_championship_table_by_division(2022, 'Serie A')
serie_a_23 = championships_controller.select_championship_table_by_division(2023, 'Serie A')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_a_22, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0    Atlético Goianiense        38        21       12         5
# 1            Corinthians        38        18       15         5
# 2           Sport Recife        38        16       15         7
# 3                 Grêmio        38        13       16         9
# 4        América Mineiro        38        12       19         7
# 5                  Ceará        38        12       18         8
# 6               Flamengo        38        11       20         7
# 7              São Paulo        38        14       11        13
# 8              Palmeiras        38        12       16        10
# 9   Athletico Paranaense        38        11       18         9
# 10            Fluminense        38        10       19         9
# 11           Chapecoense        38        10       17        11
# 12                Cuiabá        38        10       13        15
# 13      Atlético Mineiro        38        10       13        15
# 14             Juventude        38         7       20        11
# 15         International        38         8       16        14
# 16             Fortaleza        38         8       15        15
# 17                 Bahia        38         7       13        18
# 18   Red Bull Bragantino        38         5       18        15
# 19                Santos        38         6       14        18
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              29             34             -5      75
# 1              21             27             -6      69
# 2              35             28              7      63
# 3              28             21              7      55
# 4              19             17              2      55
# 5              22             19              3      54
# 6              27             22              5      53
# 7              23             26             -3      53
# 8              24             14             10      52
# 9              18             26             -8      51
# 10             24             19              5      49
# 11             25             26             -1      47
# 12             28             18             10      43
# 13             20             13              7      43
# 14             24             23              1      41
# 15             27             27              0      40
# 16             26             25              1      39
# 17             28             22              6      34
# 18             23             16              7      33
# 19             17             31            -14      32

# %%
# Define dataframe from serie a 2023


pd.DataFrame(serie_a_23, columns=header)
# Out:
#                    Clube  Partidas  Vitorias  Empates  Derrotas  \
# 0                   Avaí        38        18       14         6
# 1                   Remo        38        19       10         9
# 2              São Paulo        38        17       12         9
# 3            Corinthians        38        16       14         8
# 4                 Grêmio        38        16       11        11
# 5    Atlético Goianiense        38        14       14        10
# 6              Palmeiras        38        14       13        11
# 7          Vasco da Gama        38        14       13        11
# 8           Sport Recife        38        15        9        14
# 9                 Cuiabá        38        11       16        11
# 10             Juventude        38        12       11        15
# 11         International        38        11       14        13
# 12  Athletico Paranaense        38         9       19        10
# 13      Atlético Mineiro        38        11       13        14
# 14       América Mineiro        38        10       15        13
# 15            Fluminense        38         8       15        15
# 16           Chapecoense        38         9       12        17
# 17              Flamengo        38         7       16        15
# 18                 Ceará        38         7       14        17
# 19               Vitória        38         6       17        15
#
#     Gols Marcados  Gols Sofridos  Saldo de Gols  Pontos
# 0              34             32              2      68
# 1              27             24              3      67
# 2              29             17             12      63
# 3              25             21              4      62
# 4              25             22              3      59
# 5              27             27              0      56
# 6              36             23             13      55
# 7              25             35            -10      55
# 8              31             16             15      54
# 9              23             27             -4      49
# 10             23             23              0      47
# 11             24             23              1      47
# 12             23             29             -6      46
# 13             29             22              7      46
# 14             22             25             -3      45
# 15             15             25            -10      39
# 16             31             34             -3      39
# 17             25             21              4      37
# 18             25             28             -3      35
# 19             27             26              1      35

# %%
# Getting season 22 and 23 from champeonato brasileiro serie a

serie_b_22 = championships_controller.select_championship_table_by_division(2022, 'Serie B')
serie_b_23 = championships_controller.select_championship_table_by_division(2023, 'Serie B')

# %%
# Define dataframe from serie a 2022

pd.DataFrame(serie_b_22, columns=header)
# Out:
#                 Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0                Remo        38        20       12         6             27
# 1       Vasco da Gama        38        19       10         9             25
# 2             Vitória        38        15       13        10             28
# 3                Avaí        38        14       16         8             25
# 4         Ponte Preta        38        13       18         7             25
# 5             Brusque        38        15       11        12             42
# 6      Sampaio Corrêa        38        13       17         8             28
# 7                 CSA        38        12       18         8             26
# 8            Cruzeiro        38        12       16        10             29
# 9   Brasil de Pelotas        38        12       14        12             29
# 10              Goiás        38        12       14        12             26
# 11           Botafogo        38         9       22         7             20
# 12           Londrina        38        12       11        15             30
# 13           Coritiba        38         8       21         9             20
# 14          Confiança        38        10       13        15             19
# 15            Guarani        38         8       13        17             22
# 16          Vila Nova        38         7       15        16             21
# 17            Náutico        38         7       15        16             26
# 18           Operário        38         8       12        18             30
# 19                CRB        38         5       17        16             18
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              24              3      72
# 1              27             -2      67
# 2              29             -1      58
# 3              25              0      58
# 4              26             -1      57
# 5              22             20      56
# 6              32             -4      56
# 7              26              0      54
# 8              23              6      52
# 9              27              2      50
# 10             23              3      50
# 11             19              1      49
# 12             20             10      47
# 13             15              5      45
# 14             20             -1      43
# 15             29             -7      37
# 16             21              0      36
# 17             19              7      36
# 18             26              4      36
# 19             25             -7      32

# %%
# Define dataframe from serie a 2023

pd.DataFrame(serie_b_23, columns=header)
# Out:
#                   Clube  Partidas  Vitorias  Empates  Derrotas  Gols Marcados  \
# 0              Botafogo        38        23        9         6             25
# 1            Jacuipense        38        21        7        10             30
# 2           Botafogo-PB        38        17       16         5             26
# 3               Mirasol        38        14       17         7             30
# 4        Sampaio Corrêa        38        16       11        11             36
# 5                 Goiás        38        16        9        13             24
# 6              Coritiba        38        12       16        10             27
# 7               Brusque        38        14        9        15             24
# 8           Ponte Preta        38        12       15        11             32
# 9             Confiança        38        11       17        10             18
# 10    Brasil de Pelotas        38        11       14        13             28
# 11            Fortaleza        38        11       14        13             34
# 12               Manaus        38        11       12        15             24
# 13  Red Bull Bragantino        38        11       11        16             23
# 14             Londrina        38         5       24         9             23
# 15              Guarani        38         7       18        13             15
# 16                  CSA        38         8       14        16             20
# 17             Cruzeiro        38         6       17        15             18
# 18               Santos        38         7       14        17             30
# 19                Bahia        38         5       20        13             19
#
#     Gols Sofridos  Saldo de Gols  Pontos
# 0              34             -9      78
# 1              35             -5      70
# 2              23              3      67
# 3              31             -1      59
# 4              32              4      59
# 5              41            -17      57
# 6              18              9      52
# 7              40            -16      51
# 8              23              9      51
# 9              15              3      50
# 10             28              0      47
# 11             24             10      47
# 12             26             -2      45
# 13             28             -5      44
# 14             20              3      39
# 15             22             -7      39
# 16             26             -6      38
# 17             22             -4      35
# 18             39             -9      35
# 19             23             -4      35

# %%
"""
Analisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores
e manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados

Regulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados
pois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade
as divisoes possuem um peso de excelencia

Passo 1
Atribuir um padrão de criação de dados para jogadores de times grandes e pequenos,
baseados na divisão que eles jogam.
Para isso o confifgure devera puxar os clubes por divisão
e o data generation nao deve criar dados da maneira atual

ex:
configure -> criar jogadores skills por divisão
data_manipulation -> criar dados baseados num peso
"""
# Out:
# "\nAnalisando as tabelas é necessario aplicar um meio de padronizar o 'poder de fogo' dos clubs maiores\ne manter uma constrancia nos clubes para que consiga trazer mais riqueza aos dados\n\nRegulando a qualidade dos jogadores que atuam já pode ser uma maneira de se regularizar esses dados\npois aparente os clubes que divisoes inferiores tendem a ser campeao das superiores mesmo que na realidade\nas divisoes possuem um peso de excelencia\n\nPasso 1\nAtribuir um padrão de criação de dados para jogadores de times grandes e pequenos,\nbaseados na divisão que eles jogam.\nPara isso o confifgure devera puxar os clubes por divisão\ne o data generation nao deve criar dados da maneira atual\n\nex:\nconfigure -> criar jogadores skills por divisão\ndata_manipulation -> criar dados baseados num peso\n"
