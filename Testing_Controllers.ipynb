# %%
from db.players_controller import PlayersController

# %%
PlayersController().select_players_with_contract('2022')
# Out:
# [(9751, 'Eurico de Castro', 'Brazil', '1987', 'GK', 1.98, 80.72, 'R', 73, 1),
#  (9752, 'João Lucas Matheus', 'Brazil', '2001', 'GK', 1.93, 89.33, 'L', 70, 1),
#  (9753, 'Marquinho Cunha', 'Brazil', '1985', 'GK', 1.93, 89.56, 'R', 55, 1),
#  (9754, 'Hernán Maduro', 'Chile', '2001', 'LB', 1.82, 72.01, 'L', 86, 1),
#  (9755, 'Eric Santos', 'Brazil', '1993', 'RB', 1.86, 74.15, 'L', 53, 1),
#  (9756,
#   'Javier Orerruella',
#   'Argentina',
#   '1991',
#   'RB',
#   1.81,
#   68.76,
#   'L',
#   59,
#   1),
#  (9757, 'José Jara', 'Chile', '1993', 'CB', 1.81, 81.47, 'R', 72, 1),
#  (9758, 'Nehuén Luján', 'Uruguay', '1997', 'LB', 1.8, 66.44, 'R', 84, 1),
#  (9759, 'Brayan Gonzalez', 'Chile', '1995', 'LB', 1.87, 68.15, 'L', 84, 1),
#  (9760, 'Diego Arroyo', 'Colombia', '1993', 'LB', 1.88, 86.79, 'L', 88, 1),
#  (9761,
#   'Juan Camilo Cuellar',
#   'Colombia',
#   '1990',
#   'RB',
#   1.81,
#   67.28,
#   'L',
#   76,
#   1),
#  (9762,
#   'Juan Camilo Cañete',
#   'Uruguay',
#   '2006',
#   'RB',
#   1.85,
#   73.18,
#   'L',
#   65,
#   1),
#  (9763, 'Leandrão Valerio', 'Brazil', '1984', 'LM', 1.88, 70.9, 'L', 52, 1),
#  (9764, 'Benicio Salazar', 'Uruguay', '1991', 'LM', 1.84, 88.83, 'L', 53, 1),
#  (9765, 'Joan Viña', 'Uruguay', '1994', 'LM', 1.85, 78.84, 'L', 62, 1),
#  (9766, 'Juan Zárate', 'Uruguay', '2000', 'AM', 1.76, 86.72, 'R', 65, 1),
#  (9767, 'Nehuén Caicedo', 'Chile', '1988', 'CM', 1.73, 82.41, 'R', 88, 1),
#  (9768, 'Guto Diniz', 'Brazil', '2005', 'LM', 1.67, 70.86, 'R', 79, 1),
#  (9769, 'Enzo Castillo', 'Paraguay', '2000', 'AM', 1.73, 60.69, 'R', 81, 1),
#  (9770, 'Joan Orerruella', 'Colombia', '2004', 'AM', 1.7, 89.69, 'L', 59, 1),
#  (9771, 'Teodoro Álvarez', 'Chile', '1985', 'CM', 1.84, 81.06, 'L', 51, 1),
#  (9772, 'Carmelo Uribe', 'Argentina', '1996', 'LM', 1.83, 70.17, 'R', 61, 1),
#  (9773, 'Maurilio Betin', 'Brazil', '1992', 'RM', 1.81, 63.33, 'R', 72, 1),
#  (9774, 'Miguel Pinos', 'Colombia', '1996', 'CF', 1.63, 81.59, 'R', 74, 1),
#  (9775,
#   'Juan Pablo del Toro',
#   'Uruguay',
#   '1994',
#   'WG',
#   1.77,
#   80.31,
#   'R',
#   60,
#   1),
#  (9776, 'Angel Isla', 'Colombia', '1986', 'CF', 1.82, 75.62, 'L', 62, 1),
#  (9777, 'Nicolás Martinez', 'Uruguay', '1999', 'CF', 1.85, 76.64, 'R', 61, 1),
#  (9778, 'Enrique Garcia', 'Uruguay', '2005', 'SS', 1.89, 63.7, 'R', 58, 1),
#  (9779, 'Carlito Pellerano', 'Chile', '1994', 'WG', 1.79, 73.91, 'L', 65, 1),
#  (9780, 'Rocco Vega', 'Argentina', '1988', 'SS', 1.66, 73.28, 'R', 86, 1),
#  (9781,
#   'Javier dos Santos',
#   'Argentina',
#   '1991',
#   'GK',
#   1.9,
#   64.05,
#   'L',
#   58,
#   2),
#  (9782, 'Enrique Arboleda', 'Colombia', '1988', 'GK', 1.88, 81.32, 'L', 51, 2),
#  (9783, 'Douglas Aguila', 'Brazil', '1995', 'GK', 1.89, 89.97, 'L', 88, 2),
#  (9784, 'Benicio Salazar', 'Argentina', '1989', 'RB', 1.86, 87.11, 'L', 71, 2),
#  (9785,
#   'Juan Camilo Arroyo',
#   'Paraguay',
#   '1998',
#   'CB',
#   1.89,
#   85.9,
#   'R',
#   50,
#   2),
#  (9786,
#   'Estefano Arrascaita',
#   'Uruguay',
#   '1992',
#   'LB',
#   1.87,
#   65.13,
#   'R',
#   51,
#   2),
#  (9787, 'Renato Arantes', 'Brazil', '2006', 'CB', 1.86, 86.72, 'L', 69, 2),
#  (9788, 'Alfonso Torres', 'Paraguay', '2002', 'CB', 1.84, 68.48, 'R', 64, 2),
#  (9789, 'Juca Mesquita', 'Brazil', '2006', 'LB', 1.81, 61.44, 'R', 82, 2),
#  (9790, 'Hernán del Riego', 'Uruguay', '1993', 'CB', 1.87, 81.65, 'R', 61, 2),
#  (9791, 'Nehuén Armani', 'Uruguay', '1993', 'LB', 1.85, 88.61, 'L', 58, 2),
#  (9792,
#   'Lucas De La Muerte',
#   'Argentina',
#   '1999',
#   'CB',
#   1.82,
#   82.92,
#   'R',
#   58,
#   2),
#  (9793, 'Marlon Fagundes', 'Brazil', '2003', 'DM', 1.73, 70.27, 'L', 60, 2),
#  (9794, 'Luiz Carlos Arantes', 'Brazil', '1997', 'AM', 1.83, 74.2, 'L', 76, 2),
#  (9795,
#   'Estefano Valverde',
#   'Colombia',
#   '2004',
#   'RM',
#   1.69,
#   66.78,
#   'R',
#   67,
#   2),
#  (9796, 'Hernán Calpado', 'Argentina', '1986', 'CM', 1.67, 72.42, 'R', 72, 2),
#  (9797,
#   'Benicio Izquierdo',
#   'Argentina',
#   '2004',
#   'DM',
#   1.87,
#   89.69,
#   'L',
#   59,
#   2),
#  (9798, 'Hermán Faravelli', 'Chile', '1994', 'AM', 1.87, 72.94, 'R', 81, 2),
#  (9799, 'Fernando Maduro', 'Chile', '2005', 'DM', 1.73, 63.4, 'R', 59, 2),
#  (9800, 'Gustavo Luján', 'Argentina', '1998', 'LM', 1.61, 76.34, 'L', 69, 2),
#  (9801, 'Pepeu dos Santos', 'Brazil', '1993', 'AM', 1.71, 84.68, 'L', 50, 2),
#  (9802, 'Lucas Kuster', 'Brazil', '1999', 'LM', 1.85, 84.11, 'R', 80, 2),
#  (9803,
#   'Jarrinson Faravelli',
#   'Paraguay',
#   '1987',
#   'AM',
#   1.82,
#   82.58,
#   'L',
#   53,
#   2),
#  (9804, 'Angelo Torres', 'Colombia', '1988', 'WG', 1.86, 78.57, 'R', 69, 2),
#  (9805, 'Sebastián Arroyo', 'Chile', '1999', 'SS', 1.67, 81.71, 'R', 55, 2),
#  (9806,
#   'Angelo Montenegro',
#   'Argentina',
#   '1990',
#   'WG',
#   1.81,
#   70.48,
#   'R',
#   77,
#   2),
#  (9807, 'Luide Alvez', 'Brazil', '1984', 'CF', 1.66, 86.89, 'L', 80, 2),
#  (9808, 'Gustavo Gonzalez', 'Uruguay', '1992', 'CF', 1.75, 71.17, 'R', 55, 2),
#  (9809, 'Frederico Cuesta', 'Uruguay', '2005', 'WG', 1.88, 65.44, 'R', 58, 2),
#  (9810, 'Guido di Maria', 'Argentina', '2004', 'WG', 1.81, 73.52, 'L', 90, 2),
#  (9811, 'Teófilo Paredes', 'Paraguay', '2005', 'GK', 1.94, 62.43, 'L', 55, 3),
#  (9812, 'Bill Aquila', 'Brazil', '1985', 'GK', 1.93, 69.2, 'L', 78, 3),
#  (9813, 'Héctor Arboleda', 'Argentina', '1999', 'GK', 1.92, 64.75, 'R', 77, 3),
#  (9814, 'Filipe Frazan', 'Brazil', '2006', 'LB', 1.81, 71.64, 'R', 55, 3),
#  (9815, 'Enrique Castro', 'Paraguay', '1986', 'CB', 1.86, 74.68, 'L', 68, 3),
#  (9816, 'João Lucas Inacio', 'Brazil', '1989', 'LB', 1.88, 84.81, 'R', 67, 3),
#  (9817, 'Arlindo Lopes', 'Brazil', '1996', 'CB', 1.85, 87.08, 'L', 57, 3),
#  (9818, 'Deivid Couto', 'Brazil', '2006', 'CB', 1.89, 76.5, 'L', 90, 3),
#  (9819, 'Rubén del Riego', 'Uruguay', '1991', 'RB', 1.85, 72.39, 'L', 72, 3),
#  (9820, 'Enzo Pellerano', 'Chile', '2002', 'CB', 1.84, 61.51, 'R', 66, 3),
#  (9821, 'Yamir Maduro', 'Colombia', '1985', 'LB', 1.82, 64.32, 'L', 76, 3),
#  (9822, 'Estefano Armani', 'Chile', '1998', 'CB', 1.87, 86.46, 'L', 81, 3),
#  (9823, 'Rodrigo Sanchez', 'Colombia', '1992', 'DM', 1.72, 65.05, 'R', 78, 3),
#  (9824, 'Agustin Valverde', 'Chile', '1991', 'DM', 1.62, 69.42, 'R', 67, 3),
#  (9825, 'Tomás Murillo', 'Colombia', '1989', 'LM', 1.62, 78.28, 'L', 73, 3),
#  (9826, 'Hernán Pinos', 'Chile', '1992', 'LM', 1.83, 86.49, 'R', 89, 3),
#  (9827, 'Rocco Zeballos', 'Chile', '1995', 'DM', 1.67, 67.45, 'L', 54, 3),
#  (9828, 'Germán Viña', 'Chile', '1987', 'RM', 1.74, 64.27, 'R', 58, 3),
#  (9829, 'Patrick Rainha', 'Brazil', '1994', 'LM', 1.73, 75.05, 'L', 80, 3),
#  (9830, 'Carmelo Plaza', 'Colombia', '1995', 'DM', 1.85, 73.78, 'L', 65, 3),
#  (9831,
#   'Giovani Aránguiz',
#   'Argentina',
#   '1997',
#   'CM',
#   1.61,
#   83.46,
#   'R',
#   51,
#   3),
#  (9832, 'Stiven Vega', 'Paraguay', '2001', 'RM', 1.86, 78.39, 'R', 77, 3),
#  (9833, 'Henrique Licurgo', 'Brazil', '1985', 'DM', 1.72, 81.61, 'L', 87, 3),
#  (9834, 'Alfonso Cuellar', 'Colombia', '1995', 'WG', 1.89, 61.32, 'R', 84, 3),
#  (9835, 'Diego Sanchez', 'Paraguay', '1999', 'WG', 1.68, 83.96, 'R', 55, 3),
#  (9836, 'Joaquin Castro', 'Chile', '1990', 'WG', 1.8, 84.52, 'R', 85, 3),
#  (9837, 'Rodrigo Pellerano', 'Paraguay', '2000', 'WG', 1.72, 63.8, 'R', 75, 3),
#  (9838, 'Andrés Cuesta', 'Argentina', '1986', 'WG', 1.94, 83.29, 'L', 86, 3),
#  (9839,
#   'Juan Pablo Moreno',
#   'Argentina',
#   '1999',
#   'SS',
#   1.63,
#   78.32,
#   'R',
#   77,
#   3),
#  (9840, 'Marcão Valão', 'Brazil', '2003', 'CF', 1.64, 61.14, 'R', 55, 3),
#  (9841, 'Enrique Isla', 'Argentina', '2002', 'GK', 1.98, 90.06, 'R', 54, 4),
#  (9842, 'Leandro Pinos', 'Paraguay', '1992', 'GK', 1.94, 76.84, 'R', 86, 4),
#  (9843, 'José Rojas', 'Paraguay', '1994', 'GK', 1.96, 73.01, 'R', 63, 4),
#  (9844, 'Gustavo Rojas', 'Colombia', '1991', 'LB', 1.84, 65.41, 'L', 62, 4),
#  (9845, 'Juan Pablo Villa', 'Chile', '1993', 'LB', 1.82, 66.93, 'L', 56, 4),
#  (9846, 'Alberto Isla', 'Colombia', '1989', 'CB', 1.88, 68.43, 'L', 88, 4),
#  (9847, 'Fabián Sanchez', 'Uruguay', '1992', 'CB', 1.89, 68.44, 'L', 70, 4),
#  (9848, 'William Golvea', 'Brazil', '1984', 'RB', 1.84, 71.83, 'L', 65, 4),
#  (9849, 'Nehuén Maidana', 'Uruguay', '1991', 'LB', 1.88, 62.98, 'R', 60, 4),
#  (9850, 'Giuliano Cruz', 'Brazil', '1996', 'LB', 1.83, 76.98, 'R', 62, 4),
#  (9851, 'Rubén Vega', 'Colombia', '2006', 'RB', 1.82, 87.47, 'R', 50, 4),
#  (9852, 'Rubén di Maria', 'Colombia', '2002', 'LB', 1.84, 82.99, 'R', 75, 4),
#  (9853, 'Paolo Guerrero', 'Paraguay', '2003', 'LM', 1.62, 63.1, 'R', 76, 4),
#  (9854, 'José Vázquez', 'Paraguay', '2005', 'LM', 1.83, 72.84, 'R', 84, 4),
#  (9855, 'Andrés Villa', 'Colombia', '1995', 'RM', 1.79, 76.08, 'L', 84, 4),
#  (9856, 'Edivaldo Laranja', 'Brazil', '1994', 'DM', 1.83, 89.43, 'L', 57, 4),
#  (9857, 'Savio Cella', 'Brazil', '2004', 'DM', 1.75, 68.34, 'L', 71, 4),
#  (9858, 'Maxi López', 'Paraguay', '1991', 'LM', 1.8, 76.87, 'L', 54, 4),
#  (9859, 'Guido Murillo', 'Uruguay', '2003', 'AM', 1.78, 88.66, 'R', 58, 4),
#  (9860, 'José Villa', 'Colombia', '1992', 'CM', 1.64, 88.63, 'R', 80, 4),
#  (9861, 'Piero Faravelli', 'Argentina', '1987', 'CM', 1.8, 74.62, 'R', 69, 4),
#  (9862, 'Piero Arrascaita', 'Uruguay', '1996', 'DM', 1.69, 82.11, 'R', 76, 4),
#  (9863, 'Wilson Dias', 'Brazil', '1999', 'DM', 1.71, 61.36, 'L', 57, 4),
#  (9864, 'Esteban Izquierdo', 'Uruguay', '2006', 'WG', 1.89, 83.5, 'R', 80, 4),
#  (9865, 'Franco Plaza', 'Colombia', '1986', 'SS', 1.64, 85.56, 'R', 66, 4),
#  (9866, 'Guillermo Salazar', 'Chile', '1999', 'CF', 1.87, 80.5, 'L', 89, 4),
#  (9867, 'Lautaro Plaza', 'Paraguay', '2006', 'SS', 1.87, 71.33, 'R', 76, 4),
#  (9868, 'Esteban Torres', 'Colombia', '1996', 'WG', 1.67, 60.22, 'R', 66, 4),
#  (9869, 'Brayan Arias', 'Uruguay', '1989', 'SS', 1.86, 86.74, 'L', 79, 4),
#  (9870, 'Frederico Guerrero', 'Chile', '1991', 'CF', 1.78, 63.8, 'R', 71, 4),
#  (9871, 'Angelo Zárate', 'Colombia', '1992', 'GK', 1.95, 72.69, 'L', 73, 5),
#  (9872, 'Teodoro Rojas', 'Chile', '2004', 'GK', 1.88, 72.78, 'L', 84, 5),
#  (9873, 'Rodrigo Zeballos', 'Uruguay', '1985', 'GK', 1.91, 79.83, 'R', 64, 5),
#  (9874, 'Andrés Hurtado', 'Uruguay', '1985', 'LB', 1.82, 79.96, 'R', 82, 5),
#  (9875, 'Caco Fuzão', 'Brazil', '1991', 'LB', 1.83, 66.11, 'L', 53, 5),
#  (9876, 'Joaquin Paredes', 'Colombia', '2006', 'LB', 1.89, 68.36, 'R', 69, 5),
#  (9877, 'Guinho Crespo', 'Brazil', '1995', 'CB', 1.84, 68.21, 'R', 89, 5),
#  (9878, 'Rubén Ortiz', 'Colombia', '1989', 'LB', 1.88, 64.68, 'L', 67, 5),
#  (9879, 'Vagner Mosquito', 'Brazil', '1999', 'CB', 1.89, 62.59, 'R', 85, 5),
#  (9880, 'Germán Villa', 'Uruguay', '1991', 'CB', 1.88, 80.38, 'R', 57, 5),
#  (9881, 'Rocco Arrascaita', 'Chile', '1987', 'LB', 1.88, 69.02, 'R', 65, 5),
#  (9882, 'Carlos Mota', 'Brazil', '2005', 'LB', 1.83, 86.23, 'R', 58, 5),
#  (9883, 'Nehuén Calpado', 'Paraguay', '1999', 'CM', 1.76, 64.2, 'L', 79, 5),
#  (9884, 'Alberto Viña', 'Colombia', '1984', 'RM', 1.88, 60.13, 'R', 74, 5),
#  (9885,
#   'Sebastián Palavecino',
#   'Argentina',
#   '2005',
#   'LM',
#   1.79,
#   82.7,
#   'R',
#   61,
#   5),
#  (9886, 'Alberto Vargas', 'Paraguay', '1996', 'LM', 1.73, 72.95, 'R', 58, 5),
#  (9887,
#   'Francisco Giampaolli',
#   'Chile',
#   '1988',
#   'DM',
#   1.64,
#   83.33,
#   'R',
#   87,
#   5),
#  (9888, 'Tomás Ortiz', 'Paraguay', '1986', 'DM', 1.62, 76.5, 'R', 83, 5),
#  (9889, 'Patricio Armani', 'Paraguay', '1990', 'LM', 1.66, 84.15, 'L', 89, 5),
#  (9890, 'Piero Caicedo', 'Chile', '2005', 'CM', 1.7, 86.97, 'L', 90, 5),
#  (9891, 'Fernando Cuellar', 'Chile', '1989', 'DM', 1.75, 66.86, 'R', 59, 5),
#  (9892, 'Tomás Pavón', 'Uruguay', '2002', 'RM', 1.61, 90.73, 'L', 90, 5),
#  (9893, 'Teófilo Montenegro', 'Chile', '2002', 'DM', 1.67, 80.3, 'L', 63, 5),
#  (9894,
#   'Juan Pablo Zárate',
#   'Paraguay',
#   '2001',
#   'CF',
#   1.75,
#   63.44,
#   'R',
#   55,
#   5),
#  (9895, 'Rocco Mari', 'Paraguay', '1999', 'WG', 1.88, 66.64, 'L', 64, 5),
#  (9896, 'Raizinho Azevedo', 'Brazil', '1995', 'CF', 1.73, 85.42, 'R', 72, 5),
#  (9897, 'Rodrigo Viña', 'Argentina', '1999', 'CF', 1.61, 74.31, 'L', 78, 5),
#  (9898, 'Rodrigo Jara', 'Colombia', '2000', 'WG', 1.91, 66.07, 'L', 69, 5),
#  (9899, 'Nicolás di Santoro', 'Chile', '2002', 'CF', 1.93, 68.98, 'L', 52, 5),
#  (9900, 'Enrique Vázquez', 'Argentina', '2001', 'WG', 1.93, 78.5, 'R', 89, 5),
#  (9901, 'Alberto Cuesta', 'Chile', '2006', 'GK', 1.94, 85.45, 'R', 68, 6),
#  (9902, 'Gustavo Arroyo', 'Colombia', '1989', 'GK', 1.89, 60.91, 'R', 77, 6),
#  (9903, 'Enrique Rojas', 'Paraguay', '1986', 'GK', 1.9, 63.92, 'R', 56, 6),
#  (9904, 'Angel Cueva', 'Paraguay', '2005', 'LB', 1.89, 68.17, 'R', 50, 6),
#  (9905, 'Javier Maduro', 'Paraguay', '1993', 'CB', 1.86, 81.96, 'R', 50, 6),
#  (9906, 'Nehuén Álvarez', 'Chile', '2002', 'CB', 1.83, 71.74, 'R', 83, 6),
#  (9907, 'Angel Jara', 'Colombia', '1990', 'RB', 1.85, 63.6, 'R', 71, 6),
#  (9908, 'Emiliano Cuesta', 'Uruguay', '2003', 'CB', 1.85, 71.76, 'R', 70, 6),
#  (9909, 'Héctor Martinez', 'Paraguay', '2002', 'CB', 1.81, 72.31, 'R', 52, 6),
#  (9910, 'Aldo Jara', 'Colombia', '1992', 'CB', 1.8, 73.74, 'R', 51, 6),
#  (9911, 'Héctor Hurtado', 'Chile', '1990', 'CB', 1.85, 81.48, 'R', 62, 6),
#  (9912, 'Lucas Pellerano', 'Paraguay', '2003', 'CB', 1.87, 87.98, 'L', 64, 6),
#  (9913, 'Teófilo Moreno', 'Uruguay', '1994', 'RM', 1.78, 70.16, 'L', 87, 6),
#  (9914, 'Didiér Arias', 'Paraguay', '2006', 'RM', 1.85, 61.61, 'L', 73, 6),
#  (9915,
#   'Nicolás di Maria',
#   'Argentina',
#   '1998',
#   'LM',
#   1.82,
#   61.38,
#   'R',
#   68,
#   6),
#  (9916, 'Estefano Soto', 'Chile', '2005', 'LM', 1.87, 82.75, 'R', 86, 6),
#  (9917, 'Eugenio Pavón', 'Uruguay', '1995', 'DM', 1.85, 65.56, 'L', 65, 6),
#  (9918, 'Juninho Nascimento', 'Brazil', '1985', 'DM', 1.82, 60.4, 'L', 73, 6),
#  (9919, 'Teodoro Álvarez', 'Colombia', '1994', 'AM', 1.74, 77.88, 'R', 55, 6),
#  (9920, 'Héctor Valverde', 'Uruguay', '1993', 'RM', 1.82, 61.32, 'R', 62, 6),
#  (9921, 'Fernando Cella', 'Brazil', '1992', 'AM', 1.72, 63.26, 'R', 67, 6),
#  (9922, 'Lautaro Paredes', 'Colombia', '1991', 'AM', 1.64, 84.77, 'L', 79, 6),
#  (9923,
#   'Jarrinson Martinez',
#   'Argentina',
#   '1989',
#   'RM',
#   1.8,
#   76.3,
#   'R',
#   67,
#   6),
#  (9924, 'Alberto Mari', 'Chile', '1996', 'CF', 1.7, 74.87, 'R', 88, 6),
#  (9925, 'Ian Fuzão', 'Brazil', '2001', 'WG', 1.74, 76.71, 'L', 79, 6),
#  (9926,
#   'Angelo Orerruella',
#   'Colombia',
#   '1987',
#   'CF',
#   1.78,
#   60.98,
#   'L',
#   81,
#   6),
#  (9927,
#   'Exequiel Faravelli',
#   'Colombia',
#   '1993',
#   'CF',
#   1.9,
#   61.78,
#   'L',
#   63,
#   6),
#  (9928, 'Alfonso Faravelli', 'Chile', '2005', 'WG', 1.66, 70.5, 'R', 77, 6),
#  (9929,
#   'Franco de Arrascaeta',
#   'Paraguay',
#   '2001',
#   'SS',
#   1.87,
#   74.97,
#   'L',
#   56,
#   6),
#  (9930, 'Estefano Torres', 'Chile', '1985', 'CF', 1.95, 65.43, 'R', 89, 6),
#  (9931, 'Natan Silvestre', 'Brazil', '1991', 'GK', 1.89, 67.92, 'L', 54, 7),
#  (9932, 'Rocco Aránguiz', 'Colombia', '1994', 'GK', 1.99, 72.13, 'R', 85, 7),
#  (9933, 'Guido Castro', 'Chile', '2005', 'GK', 1.94, 75.63, 'L', 72, 7),
#  (9934, 'Didiér Valverde', 'Chile', '2005', 'LB', 1.89, 60.4, 'L', 82, 7),
#  (9935, 'Vitor Paes', 'Brazil', '2002', 'RB', 1.9, 85.54, 'R', 71, 7),
#  (9936, 'Diego Arrascaita', 'Colombia', '1999', 'LB', 1.9, 67.31, 'L', 62, 7),
#  (9937, 'Brayan Zárate', 'Chile', '2003', 'RB', 1.84, 87.96, 'R', 76, 7),
#  (9938, 'Tomás di Santoro', 'Colombia', '2005', 'LB', 1.87, 75.7, 'R', 83, 7),
#  (9939, 'Rogerio Aguiar', 'Brazil', '1990', 'RB', 1.82, 89.84, 'R', 76, 7),
#  (9940, 'Nicolás Gonzalez', 'Colombia', '1995', 'CB', 1.87, 76.98, 'R', 73, 7),
#  (9941,
#   'Esteban Banguero',
#   'Argentina',
#   '1995',
#   'LB',
#   1.84,
#   77.36,
#   'L',
#   87,
#   7),
#  (9942, 'Guillermo Borré', 'Chile', '1991', 'RB', 1.8, 79.43, 'L', 54, 7),
#  (9943,
#   'Guillermo di Santoro',
#   'Uruguay',
#   '1995',
#   'RM',
#   1.67,
#   72.56,
#   'R',
#   88,
#   7),
#  (9944, 'Angel Moreno', 'Paraguay', '1995', 'LM', 1.7, 82.76, 'L', 89, 7),
#  (9945, 'Joao Miguel Mello', 'Brazil', '2002', 'DM', 1.9, 81.47, 'R', 73, 7),
#  (9946,
#   'Luiz Carlos Silveira',
#   'Brazil',
#   '2006',
#   'DM',
#   1.67,
#   72.41,
#   'L',
#   57,
#   7),
#  (9947, 'Alberto Torres', 'Paraguay', '2005', 'CM', 1.61, 74.63, 'L', 71, 7),
#  (9948, 'Aldo Cardozo', 'Argentina', '1985', 'RM', 1.77, 87.34, 'L', 84, 7),
#  (9949, 'Fernando Bologna', 'Uruguay', '1995', 'AM', 1.63, 86.33, 'R', 74, 7),
#  (9950, 'Guillermo Plaza', 'Paraguay', '1985', 'DM', 1.89, 84.23, 'R', 57, 7),
#  (9951,
#   'José Antônio Firmino',
#   'Brazil',
#   '1988',
#   'DM',
#   1.71,
#   86.95,
#   'R',
#   65,
#   7),
#  (9952, 'Alfonso Luján', 'Argentina', '1996', 'LM', 1.68, 60.19, 'R', 55, 7),
#  (9953, 'Rafael Rojo', 'Chile', '1992', 'LM', 1.79, 62.12, 'L', 87, 7),
#  (9954, 'Andrés Ortiz', 'Paraguay', '1997', 'CF', 1.66, 82.23, 'L', 81, 7),
#  (9955,
#   'Juan Pablo del Riego',
#   'Argentina',
#   '1997',
#   'WG',
#   1.66,
#   72.55,
#   'R',
#   85,
#   7),
#  (9956, 'Paolo Soto', 'Paraguay', '1989', 'SS', 1.73, 62.48, 'R', 70, 7),
#  (9957, 'Neilton Barcelo', 'Brazil', '1992', 'SS', 1.93, 67.74, 'R', 65, 7),
#  (9958, 'Germán Hurtado', 'Paraguay', '1996', 'CF', 1.74, 69.98, 'L', 61, 7),
#  (9959, 'Ronaldo Nascimento', 'Brazil', '1990', 'WG', 1.61, 87.65, 'R', 67, 7),
#  (9960, 'Frederico Plaza', 'Paraguay', '1999', 'CF', 1.85, 60.96, 'R', 69, 7),
#  (9961, 'Piero Montenegro', 'Paraguay', '1992', 'GK', 1.89, 60.64, 'R', 72, 8),
#  (9962, 'Rubén Gomez', 'Uruguay', '1994', 'GK', 1.89, 87.17, 'L', 72, 8),
#  (9963, 'Lucas Cuesta', 'Argentina', '1987', 'GK', 1.99, 74.87, 'R', 55, 8),
#  (9964, 'Ronaldo Mico', 'Brazil', '2005', 'RB', 1.86, 68.19, 'R', 72, 8),
#  (9965, 'Yamir Valverde', 'Chile', '1996', 'LB', 1.85, 60.25, 'R', 60, 8),
#  (9966,
#   'Patricio Zeballos',
#   'Argentina',
#   '1985',
#   'LB',
#   1.89,
#   78.45,
#   'R',
#   90,
#   8),
#  (9967, 'Rubén Maidana', 'Uruguay', '1992', 'RB', 1.84, 84.21, 'R', 71, 8),
#  (9968, 'Frederico Isla', 'Uruguay', '1986', 'CB', 1.86, 65.83, 'L', 75, 8),
#  (9969, 'Angel De La Cruz', 'Argentina', '1998', 'CB', 1.87, 64.3, 'R', 69, 8),
#  (9970, 'Benicio Gonzalez', 'Paraguay', '1989', 'CB', 1.9, 75.5, 'R', 79, 8),
#  (9971, 'Leandro Rojas', 'Colombia', '2002', 'LB', 1.89, 63.95, 'L', 88, 8),
#  (9972, 'Wendel Bassols', 'Brazil', '2002', 'LB', 1.82, 78.71, 'L', 73, 8),
#  (9973, 'Lautaro Maduro', 'Colombia', '1999', 'AM', 1.88, 76.6, 'L', 53, 8),
#  (9974, 'Angel Castro', 'Argentina', '2000', 'DM', 1.76, 76.48, 'L', 63, 8),
#  (9975, 'Leandrão Menezes', 'Brazil', '1991', 'DM', 1.68, 80.83, 'R', 77, 8),
#  (9976,
#   'Giovani Giampaolli',
#   'Uruguay',
#   '1993',
#   'CM',
#   1.64,
#   69.76,
#   'R',
#   81,
#   8),
#  (9977, 'Gustavo Montenegro', 'Chile', '2002', 'DM', 1.63, 66.07, 'R', 77, 8),
#  (9978,
#   'Esteban Hernandez',
#   'Colombia',
#   '2001',
#   'DM',
#   1.72,
#   65.74,
#   'R',
#   76,
#   8),
#  (9979, 'Juan del Toro', 'Argentina', '1995', 'RM', 1.77, 65.17, 'R', 77, 8),
#  (9980, 'Miguel Salazar', 'Argentina', '2002', 'RM', 1.62, 68.46, 'R', 56, 8),
#  (9981, 'Rafael Soldano', 'Uruguay', '1984', 'CM', 1.61, 89.93, 'R', 65, 8),
#  (9982, 'Emiliano Isla', 'Paraguay', '1994', 'CM', 1.83, 88.92, 'L', 79, 8),
#  (9983, 'Carlito Zárate', 'Uruguay', '1993', 'DM', 1.7, 78.83, 'R', 79, 8),
#  (9984, 'Héctor del Riego', 'Argentina', '1999', 'CF', 1.77, 75.4, 'R', 64, 8),
#  (9985,
#   'Teófilo del Riego',
#   'Paraguay',
#   '2004',
#   'CF',
#   1.77,
#   78.22,
#   'L',
#   86,
#   8),
#  (9986, 'Hermán Diaz', 'Paraguay', '1988', 'CF', 1.79, 67.42, 'R', 69, 8),
#  (9987, 'Rogerinho Fiuza', 'Brazil', '1984', 'CF', 1.86, 63.31, 'L', 67, 8),
#  (9988, 'Omar di Santoro', 'Argentina', '1997', 'CF', 1.78, 85.71, 'L', 68, 8),
#  (9989, 'Paolo Armani', 'Colombia', '2000', 'CF', 1.8, 72.12, 'L', 53, 8),
#  (9990, 'Juan Martinez', 'Uruguay', '2001', 'WG', 1.67, 80.17, 'L', 66, 8),
#  (9991, 'Estefano Suarez', 'Uruguay', '1990', 'GK', 1.89, 77.08, 'R', 54, 9),
#  (9992, 'Catatau Matheus', 'Brazil', '2006', 'GK', 1.98, 63.88, 'R', 78, 9),
#  (9993, 'Omar Rojo', 'Paraguay', '2005', 'GK', 1.91, 86.82, 'R', 51, 9),
#  (9994, 'Eliberto Cunha', 'Brazil', '1992', 'LB', 1.8, 88.3, 'R', 75, 9),
#  (9995, 'Jorge Vargas', 'Uruguay', '1989', 'RB', 1.83, 88.12, 'R', 71, 9),
#  (9996,
#   'Fabián Palavecino',
#   'Argentina',
#   '1992',
#   'RB',
#   1.87,
#   90.79,
#   'R',
#   61,
#   9),
#  (9997, 'Agustin Reinoso', 'Uruguay', '1996', 'LB', 1.85, 63.22, 'L', 53, 9),
#  (9998, 'Didiér Valverde', 'Chile', '2004', 'CB', 1.84, 85.82, 'R', 56, 9),
#  (9999,
#   'Eugenio de Arrascaeta',
#   'Argentina',
#   '2004',
#   'LB',
#   1.81,
#   85.48,
#   'L',
#   62,
#   9),
#  (10000, 'Agustin Diaz', 'Uruguay', '1999', 'CB', 1.87, 81.36, 'R', 55, 9),
#  (10001, 'Joaquin Fontana', 'Chile', '1990', 'LB', 1.85, 79.06, 'L', 87, 9),
#  (10002, 'Angelo Vargas', 'Chile', '1999', 'RB', 1.84, 75.99, 'L', 73, 9),
#  (10003, 'Henrique Miranda', 'Brazil', '1999', 'CM', 1.83, 77.05, 'L', 68, 9),
#  (10004, 'Maxi Palavecino', 'Paraguay', '1986', 'AM', 1.73, 62.51, 'L', 90, 9),
#  (10005, 'Raizinho Mota', 'Brazil', '1997', 'DM', 1.64, 90.31, 'L', 74, 9),
#  (10006, 'Carlito Rojas', 'Argentina', '1997', 'AM', 1.73, 69.22, 'L', 76, 9),
#  (10007, 'Gustavo Vázquez', 'Colombia', '1991', 'RM', 1.87, 75.79, 'L', 83, 9),
#  (10008, 'Guillermo Uribe', 'Uruguay', '1996', 'RM', 1.69, 88.39, 'L', 55, 9),
#  (10009,
#   'Juan Pablo Martinez',
#   'Argentina',
#   '1990',
#   'RM',
#   1.78,
#   64.38,
#   'R',
#   90,
#   9),
#  (10010, 'Juliano Nunes', 'Brazil', '2005', 'RM', 1.78, 63.49, 'L', 80, 9),
#  (10011,
#   'Juan Pablo Calpado',
#   'Paraguay',
#   '1992',
#   'DM',
#   1.75,
#   61.66,
#   'L',
#   89,
#   9),
#  (10012, 'Lautaro Ortiz', 'Paraguay', '1993', 'CM', 1.63, 88.52, 'L', 75, 9),
#  (10013, 'Hermán Cueva', 'Chile', '1997', 'CM', 1.86, 87.49, 'R', 62, 9),
#  (10014, 'Samuel Teles', 'Brazil', '2004', 'WG', 1.9, 88.01, 'L', 75, 9),
#  (10015, 'Guido Armani', 'Colombia', '1985', 'CF', 1.79, 81.17, 'L', 87, 9),
#  (10016, 'Lucas Arroyo', 'Chile', '2006', 'SS', 1.74, 65.64, 'L', 53, 9),
#  (10017, 'Fabián López', 'Argentina', '2005', 'SS', 1.77, 67.2, 'L', 72, 9),
#  (10018, 'Hermán Zárate', 'Argentina', '2000', 'SS', 1.71, 71.34, 'R', 74, 9),
#  (10019, 'Teodoro Rojas', 'Paraguay', '1986', 'CF', 1.77, 72.93, 'L', 73, 9),
#  (10020, 'Héctor Plaza', 'Chile', '2003', 'SS', 1.78, 89.64, 'R', 50, 9),
#  (10021,
#   'Juan Pablo Murillo',
#   'Chile',
#   '2000',
#   'GK',
#   1.96,
#   77.95,
#   'L',
#   85,
#   10),
#  (10022,
#   'Rodrigo Aránguiz',
#   'Colombia',
#   '1986',
#   'GK',
#   1.9,
#   68.15,
#   'R',
#   63,
#   10),
#  (10023, 'Fabián Cardozo', 'Colombia', '1988', 'GK', 1.95, 85.67, 'R', 89, 10),
#  (10024, 'Rocco Arboleda', 'Paraguay', '1991', 'RB', 1.88, 70.42, 'L', 90, 10),
#  (10025, 'Germán Rojo', 'Paraguay', '2006', 'RB', 1.9, 78.57, 'L', 68, 10),
#  (10026, 'Maxi Chávez', 'Chile', '1996', 'RB', 1.82, 81.56, 'R', 70, 10),
#  (10027, 'Héctor Álvarez', 'Paraguay', '1988', 'RB', 1.84, 81.32, 'R', 59, 10),
#  (10028, 'Lautaro Borré', 'Paraguay', '1995', 'RB', 1.83, 87.01, 'R', 81, 10),
#  (10029, 'Diego Rojo', 'Uruguay', '1999', 'LB', 1.88, 74.07, 'L', 73, 10),
#  (10030,
#   'Juan Camilo Cueva',
#   'Paraguay',
#   '1999',
#   'CB',
#   1.89,
#   71.27,
#   'L',
#   79,
#   10),
#  (10031,
#   'Juan De La Muerte',
#   'Paraguay',
#   '1984',
#   'CB',
#   1.81,
#   77.92,
#   'R',
#   79,
#   10),
#  (10032, 'Carmelo Caicedo', 'Uruguay', '2005', 'RB', 1.84, 80.3, 'R', 71, 10),
#  (10033,
#   'Jarrinson Orerruella',
#   'Paraguay',
#   '1986',
#   'RM',
#   1.71,
#   88.79,
#   'R',
#   53,
#   10),
#  (10034, 'Alvaro de Abreu', 'Brazil', '2006', 'DM', 1.68, 72.22, 'L', 78, 10),
#  (10035,
#   'Nicolás Aránguiz',
#   'Uruguay',
#   '2005',
#   'LM',
#   1.77,
#   87.99,
#   'L',
#   73,
#   10),
#  (10036,
#   'Jarrinson Pinos',
#   'Colombia',
#   '1997',
#   'CM',
#   1.87,
#   60.73,
#   'L',
#   77,
#   10),
#  (10037, 'Emiliano Viña', 'Colombia', '1993', 'DM', 1.68, 68.14, 'L', 71, 10),
#  (10038, 'Nehuén Suarez', 'Uruguay', '1987', 'DM', 1.82, 86.04, 'L', 63, 10),
#  (10039, 'Franco Borré', 'Chile', '1986', 'RM', 1.86, 63.98, 'R', 84, 10),
#  (10040,
#   'Emiliano Caicedo',
#   'Colombia',
#   '1988',
#   'LM',
#   1.86,
#   80.44,
#   'R',
#   85,
#   10),
#  (10041, 'Nehuén Castro', 'Argentina', '1988', 'CM', 1.85, 86.02, 'R', 83, 10),
#  (10042,
#   'Germán Pellerano',
#   'Paraguay',
#   '1984',
#   'AM',
#   1.64,
#   88.99,
#   'R',
#   66,
#   10),
#  (10043,
#   'Fabián Montenegro',
#   'Colombia',
#   '1986',
#   'CM',
#   1.74,
#   63.96,
#   'R',
#   81,
#   10),
#  (10044,
#   'Christian Martinez',
#   'Uruguay',
#   '2004',
#   'CF',
#   1.67,
#   68.8,
#   'R',
#   66,
#   10),
#  (10045, 'Marquinho Mica', 'Brazil', '1996', 'SS', 1.91, 64.62, 'R', 87, 10),
#  (10046, 'Joaquin Cañete', 'Uruguay', '1999', 'CF', 1.82, 90.04, 'L', 71, 10),
#  (10047,
#   'Frederico Castillo',
#   'Paraguay',
#   '2002',
#   'WG',
#   1.74,
#   87.84,
#   'L',
#   87,
#   10),
#  (10048, 'Esteban Chávez', 'Uruguay', '1990', 'WG', 1.75, 78.19, 'L', 80, 10),
#  (10049, 'Joaquin Chávez', 'Argentina', '2001', 'CF', 1.65, 67.6, 'R', 59, 10),
#  (10050, 'Hernán Uribe', 'Uruguay', '1994', 'WG', 1.64, 90.13, 'L', 60, 10),
#  (10051, 'Juan del Riego', 'Paraguay', '1997', 'GK', 1.98, 78.49, 'R', 74, 11),
#  (10052,
#   'Carlos Alberto Soares',
#   'Brazil',
#   '1997',
#   'GK',
#   1.98,
#   74.27,
#   'R',
#   72,
#   11),
#  (10053, 'Lucas Ortiz', 'Uruguay', '2001', 'GK', 1.93, 75.72, 'L', 59, 11),
#  (10054, 'Cezar Lima', 'Brazil', '1991', 'LB', 1.87, 80.48, 'R', 63, 11),
#  (10055, 'Eugenio Pavón', 'Argentina', '2000', 'RB', 1.86, 83.01, 'R', 67, 11),
#  (10056,
#   'Juan Camilo Salazar',
#   'Argentina',
#   '1993',
#   'LB',
#   1.84,
#   81.07,
#   'R',
#   67,
#   11),
#  (10057, 'Rocco Castillo', 'Paraguay', '1984', 'CB', 1.88, 80.99, 'R', 52, 11),
#  (10058, 'Rubén Bologna', 'Uruguay', '1994', 'LB', 1.84, 63.96, 'R', 64, 11),
#  (10059,
#   'Fernando Murillo',
#   'Uruguay',
#   '2005',
#   'CB',
#   1.89,
#   66.43,
#   'L',
#   61,
#   11),
#  (10060, 'Piero Izquierdo', 'Paraguay', '2005', 'RB', 1.88, 83.1, 'L', 87, 11),
#  (10061,
#   'Juan Pablo di Santoro',
#   'Chile',
#   '1997',
#   'LB',
#   1.83,
#   77.6,
#   'L',
#   89,
#   11),
#  (10062, 'Maxi Pellerano', 'Chile', '1985', 'CB', 1.84, 71.67, 'R', 90, 11),
#  (10063, 'Paulo Costeira', 'Brazil', '1997', 'DM', 1.81, 70.87, 'L', 81, 11),
#  (10064, 'Arlindo Veron', 'Brazil', '2004', 'CM', 1.81, 73.23, 'R', 86, 11),
#  (10065,
#   'Maxi De La Cruz',
#   'Argentina',
#   '1998',
#   'AM',
#   1.87,
#   60.55,
#   'L',
#   72,
#   11),
#  (10066,
#   'Rafael Montenegro',
#   'Uruguay',
#   '1987',
#   'LM',
#   1.69,
#   87.97,
#   'L',
#   68,
#   11),
#  (10067, 'Alberto del Toro', 'Chile', '2001', 'CM', 1.78, 67.33, 'L', 64, 11),
#  (10068, 'Diego Sampaoli', 'Uruguay', '1986', 'CM', 1.72, 83.69, 'L', 54, 11),
#  (10069,
#   'Frederico Sampaoli',
#   'Chile',
#   '1984',
#   'AM',
#   1.68,
#   90.33,
#   'L',
#   65,
#   11),
#  (10070, 'Rodrigo Castillo', 'Chile', '2001', 'CM', 1.86, 67.74, 'R', 50, 11),
#  (10071,
#   'Emiliano Armani',
#   'Argentina',
#   '2004',
#   'RM',
#   1.77,
#   67.76,
#   'R',
#   77,
#   11),
#  (10072, 'Savarino Pera', 'Brazil', '1995', 'RM', 1.64, 90.57, 'R', 52, 11),
#  (10073,
#   'Franco De La Cruz',
#   'Uruguay',
#   '2000',
#   'AM',
#   1.83,
#   77.7,
#   'L',
#   55,
#   11),
#  (10074, 'Aldo Aránguiz', 'Chile', '1997', 'CF', 1.62, 62.04, 'R', 56, 11),
#  (10075, 'Teófilo Borré', 'Chile', '2005', 'SS', 1.61, 75.21, 'L', 63, 11),
#  (10076,
#   'Angelo Izquierdo',
#   'Argentina',
#   '2000',
#   'SS',
#   1.64,
#   69.42,
#   'R',
#   50,
#   11),
#  (10077,
#   'Leandro De La Muerte',
#   'Colombia',
#   '1993',
#   'SS',
#   1.7,
#   70.67,
#   'R',
#   71,
#   11),
#  (10078, 'Francisco Álvarez', 'Chile', '1997', 'SS', 1.93, 73.82, 'R', 72, 11),
#  (10079, 'Joan Maidana', 'Chile', '1989', 'CF', 1.93, 87.12, 'R', 60, 11),
#  (10080,
#   'Agustin dos Santos',
#   'Paraguay',
#   '2004',
#   'SS',
#   1.63,
#   77.75,
#   'L',
#   81,
#   11),
#  (10081, 'Stiven Viña', 'Uruguay', '2004', 'GK', 1.88, 81.46, 'R', 72, 12),
#  (10082,
#   'Jarrinson Cardozo',
#   'Colombia',
#   '1999',
#   'GK',
#   1.87,
#   67.88,
#   'L',
#   67,
#   12),
#  (10083, 'Yohan da Cruz', 'Brazil', '1990', 'GK', 1.92, 75.46, 'R', 87, 12),
#  (10084,
#   'Carlito Hurtado',
#   'Paraguay',
#   '1987',
#   'CB',
#   1.83,
#   77.61,
#   'R',
#   72,
#   12),
#  (10085, 'Luiz Felipe Veles', 'Brazil', '2005', 'LB', 1.9, 83.94, 'L', 61, 12),
#  (10086, 'Juan Pinos', 'Uruguay', '1998', 'RB', 1.87, 74.92, 'R', 60, 12),
#  (10087, 'Nehuén Plaza', 'Colombia', '1986', 'RB', 1.84, 81.33, 'R', 62, 12),
#  (10088, 'Germán Arroyo', 'Chile', '1988', 'RB', 1.82, 86.66, 'R', 61, 12),
#  (10089, 'Nehuén Quintero', 'Chile', '1991', 'LB', 1.84, 88.79, 'L', 55, 12),
#  (10090, 'Evandro Ribas', 'Brazil', '1986', 'RB', 1.82, 69.19, 'R', 75, 12),
#  (10091, 'Marcão Coutinho', 'Brazil', '1995', 'LB', 1.89, 70.63, 'R', 81, 12),
#  (10092,
#   'Juan Pablo Valverde',
#   'Chile',
#   '2005',
#   'RB',
#   1.84,
#   88.79,
#   'L',
#   79,
#   12),
#  (10093, 'Muriel Mello', 'Brazil', '1984', 'CM', 1.76, 69.92, 'R', 56, 12),
#  (10094,
#   'Guillermo Salazar',
#   'Paraguay',
#   '1994',
#   'LM',
#   1.65,
#   62.33,
#   'L',
#   62,
#   12),
#  (10095,
#   'Miguel Pellerano',
#   'Colombia',
#   '2001',
#   'CM',
#   1.82,
#   87.7,
#   'L',
#   76,
#   12),
#  (10096,
#   'Juan Camilo Bologna',
#   'Chile',
#   '1997',
#   'RM',
#   1.87,
#   85.25,
#   'R',
#   56,
#   12),
#  (10097, 'Guinho Ribeiro', 'Brazil', '1984', 'AM', 1.81, 88.58, 'R', 85, 12),
#  (10098,
#   'Francisco Silvestre',
#   'Brazil',
#   '1996',
#   'AM',
#   1.63,
#   65.24,
#   'R',
#   68,
#   12),
#  (10099, 'Aldo Cueva', 'Paraguay', '1984', 'AM', 1.65, 83.25, 'L', 69, 12),
#  (10100, 'Christian Arroyo', 'Chile', '1984', 'CM', 1.72, 87.37, 'L', 50, 12),
#  (10101, 'Anderson Costa', 'Brazil', '1998', 'LM', 1.86, 67.83, 'L', 66, 12),
#  (10102,
#   'Paolo Hernandez',
#   'Paraguay',
#   '1993',
#   'CM',
#   1.71,
#   70.17,
#   'R',
#   89,
#   12),
#  (10103, 'Enzo Martinez', 'Chile', '1988', 'DM', 1.75, 70.42, 'R', 80, 12),
#  (10104,
#   'Rodrigo Giampaolli',
#   'Uruguay',
#   '1984',
#   'WG',
#   1.72,
#   86.69,
#   'L',
#   74,
#   12),
#  (10105,
#   'Fabián Valverde',
#   'Paraguay',
#   '2002',
#   'WG',
#   1.66,
#   65.04,
#   'L',
#   88,
#   12),
#  (10106, 'Gustavo Arias', 'Chile', '2000', 'WG', 1.77, 66.53, 'R', 73, 12),
#  (10107, 'Enrique Arroyo', 'Chile', '1995', 'SS', 1.62, 90.64, 'R', 77, 12),
#  (10108,
#   'Francisco Maidana',
#   'Argentina',
#   '2004',
#   'SS',
#   1.7,
#   76.2,
#   'R',
#   66,
#   12),
#  (10109, 'Brayan Vargas', 'Chile', '2006', 'SS', 1.71, 68.3, 'L', 76, 12),
#  (10110, 'Ronaldo Assad', 'Brazil', '1994', 'CF', 1.9, 88.63, 'L', 88, 12),
#  (10111, 'Edmundo Burca', 'Brazil', '1985', 'GK', 1.93, 65.03, 'R', 66, 13),
#  (10112, 'Watson de Castro', 'Brazil', '1998', 'GK', 1.9, 81.24, 'R', 83, 13),
#  (10113,
#   'Exequiel Orerruella',
#   'Uruguay',
#   '1988',
#   'GK',
#   1.97,
#   80.66,
#   'R',
#   82,
#   13),
#  (10114,
#   'Esteban Salazar',
#   'Colombia',
#   '1985',
#   'RB',
#   1.87,
#   79.26,
#   'L',
#   78,
#   13),
#  (10115, 'Lautaro Fontana', 'Chile', '2000', 'CB', 1.84, 82.64, 'R', 73, 13),
#  (10116, 'Alfonso Castillo', 'Chile', '1996', 'CB', 1.87, 61.16, 'L', 83, 13),
#  (10117, 'Enrique Viña', 'Paraguay', '1992', 'RB', 1.81, 72.61, 'R', 81, 13),
#  (10118, 'Joaquin Isla', 'Argentina', '1994', 'CB', 1.8, 76.21, 'L', 65, 13),
#  (10119,
#   'Tomás di Santoro',
#   'Colombia',
#   '2002',
#   'LB',
#   1.84,
#   82.72,
#   'L',
#   59,
#   13),
#  (10120, 'Carmelo Uribe', 'Chile', '2000', 'CB', 1.81, 64.36, 'R', 60, 13),
#  (10121, 'Paolo di Santoro', 'Chile', '1996', 'CB', 1.85, 69.6, 'R', 77, 13),
#  (10122,
#   'Aldo Montenegro',
#   'Colombia',
#   '2001',
#   'RB',
#   1.81,
#   68.92,
#   'R',
#   55,
#   13),
#  (10123, 'Giovani Ortiz', 'Colombia', '1991', 'CM', 1.61, 88.64, 'L', 81, 13),
#  (10124, 'Angelo Castro', 'Argentina', '1998', 'AM', 1.62, 79.22, 'R', 50, 13),
#  (10125, 'Enzo Arouca', 'Brazil', '1993', 'LM', 1.75, 75.66, 'R', 57, 13),
#  (10126,
#   'Juan Camilo Arias',
#   'Colombia',
#   '1988',
#   'RM',
#   1.81,
#   68.48,
#   'R',
#   70,
#   13),
#  (10127,
#   'Fernando Faravelli',
#   'Uruguay',
#   '1995',
#   'CM',
#   1.81,
#   72.03,
#   'L',
#   82,
#   13),
#  (10128, 'Jorge Arroyo', 'Uruguay', '1997', 'DM', 1.82, 63.83, 'L', 65, 13),
#  (10129, 'Icaro Mendes', 'Brazil', '1984', 'LM', 1.85, 81.65, 'L', 72, 13),
#  (10130, 'Rafael Arrascaita', 'Chile', '1992', 'DM', 1.65, 75.5, 'L', 69, 13),
#  (10131, 'Maxi Pinos', 'Chile', '1995', 'CM', 1.85, 69.61, 'L', 50, 13),
#  (10132,
#   'Lautaro del Toro',
#   'Uruguay',
#   '1997',
#   'LM',
#   1.75,
#   70.27,
#   'L',
#   66,
#   13),
#  (10133, 'Diego Viña', 'Colombia', '2004', 'RM', 1.71, 74.08, 'L', 71, 13),
#  (10134, 'Leandro Álvarez', 'Chile', '1993', 'WG', 1.76, 72.39, 'L', 85, 13),
#  (10135, 'Jander Nazario', 'Brazil', '1997', 'CF', 1.93, 69.47, 'L', 56, 13),
#  (10136, 'Carlito Cuesta', 'Chile', '1985', 'WG', 1.81, 79.87, 'R', 73, 13),
#  (10137, 'Rodrigo Moreno', 'Colombia', '1996', 'SS', 1.88, 64.5, 'R', 78, 13),
#  (10138, 'Omar Cueva', 'Argentina', '2006', 'SS', 1.79, 71.65, 'R', 73, 13),
#  (10139, 'Javier Pellerano', 'Chile', '1994', 'WG', 1.9, 74.89, 'R', 50, 13),
#  (10140, 'Joaquin Gomez', 'Colombia', '1986', 'CF', 1.73, 80.55, 'R', 83, 13),
#  (10141, 'Diego Arias', 'Paraguay', '2006', 'GK', 1.94, 83.19, 'L', 55, 14),
#  (10142, 'Diego Sanchez', 'Colombia', '1995', 'GK', 1.95, 74.45, 'R', 62, 14),
#  (10143, 'Santiago López', 'Chile', '1993', 'GK', 1.98, 89.49, 'L', 78, 14),
#  (10144, 'Alejandro Álvarez', 'Chile', '2005', 'LB', 1.85, 74.03, 'L', 64, 14),
#  (10145,
#   'Carlito de Arrascaeta',
#   'Colombia',
#   '2000',
#   'RB',
#   1.81,
#   60.04,
#   'L',
#   60,
#   14),
#  (10146,
#   'Juan Pablo Murillo',
#   'Paraguay',
#   '2003',
#   'CB',
#   1.87,
#   62.64,
#   'L',
#   67,
#   14),
#  (10147, 'Guido Diaz', 'Chile', '1987', 'LB', 1.9, 84.16, 'L', 71, 14),
#  (10148,
#   'Miguel Arrascaita',
#   'Colombia',
#   '1996',
#   'RB',
#   1.86,
#   86.95,
#   'R',
#   70,
#   14),
#  (10149, 'Nicolás Castro', 'Colombia', '2000', 'RB', 1.88, 88.25, 'R', 56, 14),
#  (10150, 'Diego Martinez', 'Chile', '2003', 'LB', 1.83, 75.22, 'L', 61, 14),
#  (10151, 'Didiér Zárate', 'Uruguay', '1998', 'RB', 1.88, 83.03, 'R', 54, 14),
#  (10152, 'Maurilio Carmona', 'Brazil', '1985', 'RB', 1.89, 80.5, 'L', 82, 14),
#  (10153,
#   'Juan Camilo Arrascaita',
#   'Chile',
#   '1994',
#   'LM',
#   1.83,
#   60.01,
#   'L',
#   84,
#   14),
#  (10154, 'Sandro Limeira', 'Brazil', '1988', 'RM', 1.84, 79.68, 'R', 64, 14),
#  (10155, 'Esteban Suarez', 'Uruguay', '2006', 'DM', 1.74, 86.9, 'R', 90, 14),
#  (10156, 'Victor Damião', 'Brazil', '1987', 'AM', 1.78, 68.72, 'R', 88, 14),
#  (10157,
#   'Teófilo Maidana',
#   'Colombia',
#   '1999',
#   'AM',
#   1.82,
#   70.03,
#   'R',
#   78,
#   14),
#  (10158, "Edmundo D'avila", 'Brazil', '1985', 'CM', 1.64, 72.63, 'L', 53, 14),
#  (10159, 'Jamal Silvestre', 'Brazil', '2005', 'RM', 1.64, 60.89, 'L', 79, 14),
#  (10160, 'Lautaro Mari', 'Uruguay', '1989', 'RM', 1.75, 65.66, 'L', 65, 14),
#  (10161, 'Felipi Celso', 'Brazil', '2002', 'LM', 1.79, 66.4, 'L', 62, 14),
#  (10162, 'Héctor Calpado', 'Chile', '2002', 'AM', 1.7, 85.14, 'R', 64, 14),
#  (10163, 'Patricio Garcia', 'Uruguay', '1992', 'LM', 1.64, 80.41, 'L', 89, 14),
#  (10164, 'Jarrinson Mari', 'Chile', '2002', 'SS', 1.83, 88.02, 'R', 64, 14),
#  (10165,
#   'Nehuén de Arrascaeta',
#   'Colombia',
#   '1997',
#   'WG',
#   1.94,
#   88.84,
#   'L',
#   60,
#   14),
#  (10166,
#   'Luiz Manoel Aguila',
#   'Brazil',
#   '2003',
#   'SS',
#   1.8,
#   68.21,
#   'L',
#   72,
#   14),
#  (10167,
#   'Teófilo Sampaoli',
#   'Argentina',
#   '1994',
#   'CF',
#   1.74,
#   63.86,
#   'R',
#   63,
#   14),
#  (10168,
#   'Jarrinson De La Cruz',
#   'Chile',
#   '2000',
#   'WG',
#   1.87,
#   84.98,
#   'L',
#   53,
#   14),
#  (10169,
#   'Giovani Izquierdo',
#   'Colombia',
#   '1992',
#   'SS',
#   1.79,
#   79.33,
#   'L',
#   57,
#   14),
#  (10170, 'Iván del Riego', 'Paraguay', '2005', 'CF', 1.82, 79.14, 'L', 83, 14),
#  (10171, 'Santiago Paredes', 'Uruguay', '1995', 'GK', 1.95, 85.8, 'L', 73, 15),
#  (10172, 'Tomás Gonzalez', 'Chile', '1986', 'GK', 1.95, 86.34, 'L', 76, 15),
#  (10173, 'Teodoro Pavón', 'Chile', '2001', 'GK', 1.88, 81.46, 'L', 85, 15),
#  (10174,
#   'Frederico Vázquez',
#   'Argentina',
#   '1998',
#   'CB',
#   1.81,
#   60.5,
#   'L',
#   87,
#   15),
#  (10175, 'Lucas Pellerano', 'Uruguay', '1995', 'RB', 1.88, 73.1, 'L', 75, 15),
#  (10176, 'Santiago Soto', 'Paraguay', '2003', 'CB', 1.82, 81.66, 'L', 56, 15),
#  (10177, 'Paulo Costeira', 'Brazil', '1998', 'CB', 1.82, 82.59, 'R', 54, 15),
#  (10178, 'Giovani Nogueira', 'Brazil', '1999', 'CB', 1.83, 62.63, 'L', 63, 15),
#  (10179, 'George Aguila', 'Brazil', '1990', 'RB', 1.87, 67.09, 'R', 80, 15),
#  (10180,
#   'Francisco Giampaolli',
#   'Argentina',
#   '2001',
#   'RB',
#   1.9,
#   88.89,
#   'R',
#   65,
#   15),
#  (10181, 'Exequiel Zárate', 'Chile', '2002', 'LB', 1.88, 86.95, 'L', 68, 15),
#  (10182, 'Nehuén Calpado', 'Chile', '1987', 'RB', 1.85, 87.78, 'L', 57, 15),
#  (10183, 'Felipe Beltrão', 'Brazil', '1989', 'RM', 1.88, 65.31, 'R', 64, 15),
#  (10184, 'Leandro Zárate', 'Uruguay', '1987', 'CM', 1.79, 69.47, 'R', 65, 15),
#  (10185,
#   'Carmelo Álvarez',
#   'Paraguay',
#   '1989',
#   'AM',
#   1.88,
#   69.24,
#   'R',
#   62,
#   15),
#  (10186, 'Benicio del Toro', 'Chile', '2000', 'RM', 1.82, 76.23, 'L', 80, 15),
#  (10187,
#   'Alberto Valverde',
#   'Colombia',
#   '1998',
#   'AM',
#   1.74,
#   73.28,
#   'R',
#   68,
#   15),
#  (10188, 'José Viña', 'Uruguay', '1996', 'AM', 1.83, 81.83, 'R', 67, 15),
#  (10189,
#   'Joaquin Vázquez',
#   'Colombia',
#   '1992',
#   'LM',
#   1.81,
#   85.62,
#   'R',
#   62,
#   15),
#  (10190, 'Omar Rojo', 'Chile', '1996', 'LM', 1.71, 76.71, 'R', 54, 15),
#  (10191, 'Manoel Falcao', 'Brazil', '1990', 'RM', 1.66, 72.13, 'L', 86, 15),
#  (10192,
#   'Carmelo Palavecino',
#   'Argentina',
#   '2006',
#   'RM',
#   1.9,
#   63.86,
#   'L',
#   71,
#   15),
#  (10193,
#   'Carmelo de Arrascaeta',
#   'Argentina',
#   '1994',
#   'RM',
#   1.85,
#   77.98,
#   'R',
#   61,
#   15),
#  (10194, 'Lucas López', 'Chile', '1986', 'WG', 1.67, 65.82, 'R', 85, 15),
#  (10195, 'Héctor Maduro', 'Uruguay', '2003', 'WG', 1.89, 83.27, 'R', 73, 15),
#  (10196, 'Arlindo de Paula', 'Brazil', '2005', 'SS', 1.61, 78.89, 'R', 72, 15),
#  (10197,
#   'Lautaro Arrascaita',
#   'Uruguay',
#   '1988',
#   'SS',
#   1.74,
#   80.02,
#   'R',
#   65,
#   15),
#  (10198, 'Carmelo Plaza', 'Uruguay', '1985', 'CF', 1.74, 86.05, 'L', 55, 15),
#  (10199,
#   'Enrique Giampaolli',
#   'Uruguay',
#   '1993',
#   'WG',
#   1.9,
#   72.9,
#   'L',
#   83,
#   15),
#  (10200, 'Fabián Ortiz', 'Paraguay', '2000', 'WG', 1.74, 77.64, 'L', 67, 15),
#  (10201, 'Gustavo Cuellar', 'Colombia', '1985', 'GK', 1.96, 88.3, 'L', 80, 16),
#  (10202, 'Didiér Viña', 'Colombia', '1996', 'GK', 1.93, 60.69, 'L', 78, 16),
#  (10203, 'Diego Garcia', 'Colombia', '1989', 'GK', 1.92, 90.56, 'L', 86, 16),
#  (10204,
#   'Juan Camilo De La Cruz',
#   'Paraguay',
#   '2001',
#   'RB',
#   1.8,
#   85.95,
#   'L',
#   78,
#   16),
#  (10205,
#   'Rodrigo Salazar',
#   'Argentina',
#   '1992',
#   'CB',
#   1.86,
#   86.93,
#   'R',
#   74,
#   16),
#  (10206, 'Nicolás Uribe', 'Colombia', '1997', 'CB', 1.84, 63.98, 'L', 58, 16),
#  (10207, 'Rocco Arboleda', 'Paraguay', '1995', 'CB', 1.83, 70.16, 'R', 78, 16),
#  (10208, 'Benicio Rojo', 'Argentina', '2000', 'CB', 1.88, 60.53, 'L', 61, 16),
#  (10209, 'Alvaro Varanda', 'Brazil', '1985', 'LB', 1.88, 68.05, 'L', 67, 16),
#  (10210, 'Patricio Mari', 'Chile', '1994', 'LB', 1.86, 83.05, 'L', 70, 16),
#  (10211,
#   'Emiliano Valverde',
#   'Colombia',
#   '2001',
#   'LB',
#   1.85,
#   86.78,
#   'R',
#   58,
#   16),
#  (10212, 'Giovani Uribe', 'Paraguay', '1987', 'LB', 1.84, 77.72, 'R', 71, 16),
#  (10213,
#   'Carlos Victor Ribas',
#   'Brazil',
#   '1985',
#   'DM',
#   1.73,
#   69.86,
#   'L',
#   74,
#   16),
#  (10214, 'Tomás Jara', 'Argentina', '1996', 'RM', 1.84, 65.31, 'R', 79, 16),
#  (10215, 'Vini Roxo', 'Brazil', '1999', 'DM', 1.6, 82.24, 'L', 60, 16),
#  (10216, 'Hermán Maidana', 'Uruguay', '1992', 'CM', 1.89, 77.47, 'L', 77, 16),
#  (10217,
#   'Teodoro Quintero',
#   'Argentina',
#   '1999',
#   'AM',
#   1.75,
#   64.51,
#   'L',
#   65,
#   16),
#  (10218, 'Joan Soto', 'Colombia', '1988', 'AM', 1.82, 78.41, 'R', 50, 16),
#  (10219, 'Juan Orerruella', 'Chile', '2005', 'AM', 1.66, 66.09, 'L', 74, 16),
#  (10220, 'Lucas Pinos', 'Chile', '1996', 'AM', 1.83, 70.89, 'L', 56, 16),
#  (10221,
#   'Joaquin Fontana',
#   'Paraguay',
#   '1988',
#   'DM',
#   1.87,
#   62.63,
#   'L',
#   67,
#   16),
#  (10222, 'Eduardo Nazario', 'Brazil', '1991', 'CM', 1.65, 78.51, 'R', 76, 16),
#  (10223, 'Rocco Caicedo', 'Colombia', '1985', 'CM', 1.77, 74.5, 'L', 78, 16),
#  (10224, 'Renato Mico', 'Brazil', '1999', 'CF', 1.88, 71.76, 'L', 54, 16),
#  (10225, 'Jarrinson Villa', 'Uruguay', '1991', 'SS', 1.75, 81.33, 'L', 67, 16),
#  (10226, 'Andrey Camargo', 'Brazil', '1997', 'WG', 1.77, 87.51, 'L', 58, 16),
#  (10227, 'Omar Rojas', 'Colombia', '2002', 'CF', 1.71, 70.73, 'R', 60, 16),
#  (10228, 'Javier Vega', 'Chile', '1990', 'SS', 1.91, 76.54, 'L', 66, 16),
#  (10229, 'Héctor Murillo', 'Chile', '1989', 'CF', 1.74, 60.65, 'R', 63, 16),
#  (10230, 'Carlito Garcia', 'Colombia', '2000', 'SS', 1.73, 77.7, 'R', 72, 16),
#  (10231,
#   'Juan Pablo Villa',
#   'Argentina',
#   '1997',
#   'GK',
#   1.93,
#   71.47,
#   'R',
#   50,
#   17),
#  (10232, 'Patricio Vázquez', 'Chile', '1988', 'GK', 1.95, 61.76, 'L', 69, 17),
#  (10233,
#   'Andrés Arrascaita',
#   'Argentina',
#   '2000',
#   'GK',
#   1.95,
#   86.97,
#   'L',
#   57,
#   17),
#  (10234, 'Carlito Ortiz', 'Paraguay', '1996', 'RB', 1.86, 80.92, 'R', 56, 17),
#  (10235, 'Nicolás Castillo', 'Chile', '2000', 'LB', 1.86, 77.94, 'L', 69, 17),
#  (10236,
#   'Exequiel Montenegro',
#   'Chile',
#   '1984',
#   'CB',
#   1.81,
#   77.34,
#   'R',
#   57,
#   17),
#  (10237, 'Esteban Rojas', 'Colombia', '1995', 'LB', 1.85, 61.09, 'R', 56, 17),
#  (10238, 'Angel Martinez', 'Colombia', '2003', 'RB', 1.9, 82.27, 'R', 61, 17),
#  (10239, 'Franco Pavón', 'Paraguay', '2002', 'LB', 1.81, 90.4, 'R', 70, 17),
#  (10240,
#   'Carmelo Maidana',
#   'Colombia',
#   '1987',
#   'RB',
#   1.87,
#   87.33,
#   'R',
#   60,
#   17),
#  (10241, 'Henry Burca', 'Brazil', '2000', 'CB', 1.88, 90.43, 'R', 63, 17),
#  (10242,
#   'Juan Pablo Castillo',
#   'Argentina',
#   '1985',
#   'CB',
#   1.87,
#   85.35,
#   'L',
#   75,
#   17),
#  (10243, 'Andrés Torres', 'Argentina', '1997', 'DM', 1.87, 68.97, 'R', 61, 17),
#  (10244,
#   'Carlito Paredes',
#   'Colombia',
#   '1991',
#   'LM',
#   1.75,
#   89.09,
#   'R',
#   66,
#   17),
#  (10245, 'Juan Sanchez', 'Chile', '1999', 'AM', 1.88, 79.25, 'L', 54, 17),
#  (10246,
#   'Emiliano Soldano',
#   'Uruguay',
#   '1986',
#   'LM',
#   1.84,
#   82.04,
#   'R',
#   88,
#   17),
#  (10247, 'Andrés Cañete', 'Uruguay', '1995', 'CM', 1.67, 60.84, 'R', 85, 17),
#  (10248, 'Angelo Arrascaita', 'Chile', '2001', 'CM', 1.81, 77.78, 'L', 51, 17),
#  (10249, 'Tales Santos', 'Brazil', '1994', 'LM', 1.63, 69.26, 'R', 66, 17),
#  (10250,
#   'Jarrinson Cuesta',
#   'Colombia',
#   '2003',
#   'AM',
#   1.76,
#   90.36,
#   'R',
#   72,
#   17),
#  (10251, 'Nicolás Cuesta', 'Uruguay', '1993', 'LM', 1.8, 78.7, 'L', 50, 17),
#  (10252, 'Yamir Cardozo', 'Uruguay', '1988', 'LM', 1.8, 66.5, 'R', 68, 17),
#  (10253,
#   'Joaquin Vázquez',
#   'Paraguay',
#   '2001',
#   'DM',
#   1.85,
#   80.34,
#   'R',
#   69,
#   17),
#  (10254,
#   'Piero Palavecino',
#   'Colombia',
#   '1988',
#   'CF',
#   1.8,
#   81.29,
#   'R',
#   56,
#   17),
#  (10255,
#   'Juan Pablo Cuesta',
#   'Colombia',
#   '1986',
#   'WG',
#   1.74,
#   60.09,
#   'R',
#   51,
#   17),
#  (10256, 'Jarrinson Borré', 'Uruguay', '2001', 'WG', 1.92, 87.08, 'R', 69, 17),
#  (10257, 'Lautaro Viña', 'Chile', '1996', 'CF', 1.61, 68.21, 'R', 68, 17),
#  (10258, 'Javier Gonzalez', 'Uruguay', '1998', 'CF', 1.62, 75.83, 'L', 77, 17),
#  (10259, 'Enzo Armani', 'Argentina', '1986', 'CF', 1.81, 65.78, 'L', 88, 17),
#  (10260,
#   'Juan Pablo Chávez',
#   'Colombia',
#   '1985',
#   'WG',
#   1.82,
#   89.18,
#   'R',
#   51,
#   17),
#  (10261,
#   'Benicio de Arrascaeta',
#   'Colombia',
#   '1995',
#   'GK',
#   1.96,
#   80.93,
#   'L',
#   61,
#   18),
#  (10262, 'Alberto Valverde', 'Chile', '1985', 'GK', 1.98, 85.47, 'R', 51, 18),
#  (10263, 'Nicolas Leitão', 'Brazil', '2003', 'GK', 1.95, 73.42, 'R', 63, 18),
#  (10264,
#   'Agustin De La Cruz',
#   'Argentina',
#   '2002',
#   'RB',
#   1.86,
#   77.4,
#   'L',
#   66,
#   18),
#  (10265, 'Rubén Cueva', 'Uruguay', '1992', 'LB', 1.84, 89.71, 'R', 67, 18),
#  (10266, 'Victor Neves', 'Brazil', '1992', 'RB', 1.83, 66.79, 'L', 51, 18),
#  (10267, 'Tomás Villa', 'Paraguay', '1987', 'CB', 1.89, 70.2, 'L', 58, 18),
#  (10268, 'Madson Lobo', 'Brazil', '1984', 'CB', 1.82, 76.56, 'L', 79, 18),
#  (10269, 'Wando Couto', 'Brazil', '1996', 'RB', 1.86, 90.82, 'L', 67, 18),
#  (10270, 'Franco di Maria', 'Chile', '2001', 'LB', 1.86, 74.93, 'L', 52, 18),
#  (10271,
#   'Enrique di Santoro',
#   'Uruguay',
#   '2001',
#   'RB',
#   1.89,
#   68.88,
#   'R',
#   79,
#   18),
#  (10272, 'Elizeu Valerio', 'Brazil', '2004', 'CB', 1.84, 86.17, 'R', 61, 18),
#  (10273, 'Iván Chávez', 'Uruguay', '2005', 'LM', 1.65, 61.98, 'R', 53, 18),
#  (10274,
#   'Brayan dos Santos',
#   'Paraguay',
#   '1997',
#   'AM',
#   1.78,
#   78.49,
#   'R',
#   75,
#   18),
#  (10275,
#   'Gustavo Paredes',
#   'Colombia',
#   '1989',
#   'CM',
#   1.76,
#   88.88,
#   'R',
#   73,
#   18),
#  (10276, 'Agustin Salazar', 'Colombia', '1987', 'LM', 1.78, 86.5, 'R', 83, 18),
#  (10277,
#   'Agustin Palavecino',
#   'Argentina',
#   '1999',
#   'AM',
#   1.68,
#   65.93,
#   'R',
#   62,
#   18),
#  (10278, 'Iván Salazar', 'Colombia', '1998', 'DM', 1.63, 62.34, 'R', 55, 18),
#  (10279, 'Joan del Riego', 'Colombia', '2004', 'DM', 1.85, 78.4, 'R', 78, 18),
#  (10280, 'Andrés Cueva', 'Chile', '2003', 'CM', 1.68, 72.43, 'L', 69, 18),
#  (10281, 'Teodoro Banguero', 'Chile', '2004', 'CM', 1.75, 78.75, 'L', 74, 18),
#  (10282, 'Joaquin Torres', 'Uruguay', '2001', 'AM', 1.72, 90.17, 'R', 76, 18),
#  (10283, 'Franco Cardozo', 'Chile', '1992', 'LM', 1.83, 78.28, 'L', 61, 18),
#  (10284,
#   'Washington Viveiro',
#   'Brazil',
#   '1984',
#   'CF',
#   1.91,
#   84.94,
#   'R',
#   78,
#   18),
#  (10285, 'Lucas Aránguiz', 'Argentina', '1998', 'CF', 1.77, 65.8, 'R', 90, 18),
#  (10286, 'Exequiel Vega', 'Uruguay', '1988', 'WG', 1.89, 61.37, 'L', 56, 18),
#  (10287, 'Nicolás Pavón', 'Paraguay', '1985', 'WG', 1.64, 75.46, 'R', 67, 18),
#  (10288,
#   'Angelo Vázquez',
#   'Argentina',
#   '2006',
#   'WG',
#   1.75,
#   89.19,
#   'L',
#   78,
#   18),
#  (10289,
#   'Teodoro Martinez',
#   'Uruguay',
#   '1997',
#   'WG',
#   1.64,
#   63.92,
#   'R',
#   84,
#   18),
#  (10290, 'Cezar Lira', 'Brazil', '1986', 'WG', 1.61, 62.86, 'L', 83, 18),
#  (10291, 'Enzo Pavón', 'Uruguay', '1994', 'GK', 1.96, 76.86, 'L', 54, 19),
#  (10292,
#   'Alejandro Cueva',
#   'Argentina',
#   '2005',
#   'GK',
#   1.97,
#   84.97,
#   'R',
#   60,
#   19),
#  (10293, 'Paolo Castro', 'Chile', '1995', 'GK', 1.97, 67.3, 'L', 72, 19),
#  (10294, 'Leandro Borré', 'Argentina', '1987', 'LB', 1.86, 90.37, 'L', 72, 19),
#  (10295, 'José dos Santos', 'Chile', '1997', 'CB', 1.89, 85.24, 'L', 90, 19),
#  (10296, 'Fernando Cañete', 'Uruguay', '1997', 'LB', 1.85, 86.42, 'L', 70, 19),
#  (10297,
#   'Germán Palavecino',
#   'Uruguay',
#   '1987',
#   'CB',
#   1.82,
#   86.86,
#   'L',
#   81,
#   19),
#  (10298, 'Maurilio Aquila', 'Brazil', '1999', 'CB', 1.81, 87.36, 'R', 64, 19),
#  (10299, 'Caique dos Santos', 'Brazil', '1998', 'CB', 1.87, 72.7, 'L', 52, 19),
#  (10300, 'Brayan Caicedo', 'Colombia', '1990', 'LB', 1.89, 61.12, 'R', 71, 19),
#  (10301, 'Vitor Poeta', 'Brazil', '2002', 'RB', 1.9, 89.39, 'R', 77, 19),
#  (10302, 'Yamir Torres', 'Colombia', '1986', 'LB', 1.85, 65.76, 'R', 86, 19),
#  (10303, 'Francisco Ortiz', 'Colombia', '1985', 'CM', 1.8, 66.15, 'R', 68, 19),
#  (10304, 'Eugenio del Toro', 'Uruguay', '1996', 'CM', 1.8, 88.77, 'R', 58, 19),
#  (10305,
#   'Patricio Zárate',
#   'Argentina',
#   '1994',
#   'DM',
#   1.7,
#   89.06,
#   'R',
#   89,
#   19),
#  (10306,
#   'Alfonso Aránguiz',
#   'Colombia',
#   '1993',
#   'AM',
#   1.6,
#   73.69,
#   'L',
#   62,
#   19),
#  (10307, 'Nehuén Fontana', 'Colombia', '1990', 'LM', 1.77, 68.75, 'L', 90, 19),
#  (10308,
#   'Sebastián Izquierdo',
#   'Colombia',
#   '2006',
#   'CM',
#   1.73,
#   72.09,
#   'L',
#   59,
#   19),
#  (10309, 'Leandrão Reis', 'Brazil', '2005', 'DM', 1.82, 73.19, 'R', 52, 19),
#  (10310, 'Fabián Vázquez', 'Colombia', '1997', 'AM', 1.64, 69.78, 'L', 67, 19),
#  (10311,
#   'Benicio Valverde',
#   'Argentina',
#   '1997',
#   'CM',
#   1.63,
#   80.9,
#   'L',
#   50,
#   19),
#  (10312, 'Germán López', 'Paraguay', '1996', 'AM', 1.76, 72.82, 'L', 55, 19),
#  (10313, 'Jorge Soldano', 'Uruguay', '1999', 'LM', 1.73, 77.52, 'L', 87, 19),
#  (10314, 'Guillermo Mari', 'Chile', '1995', 'WG', 1.91, 70.29, 'L', 59, 19),
#  (10315,
#   'Jorge Orerruella',
#   'Colombia',
#   '1989',
#   'CF',
#   1.78,
#   85.99,
#   'R',
#   62,
#   19),
#  (10316, 'Patricio Pavón', 'Colombia', '1998', 'CF', 1.85, 72.07, 'L', 79, 19),
#  (10317,
#   'Esteban Arroyo',
#   'Argentina',
#   '1996',
#   'CF',
#   1.74,
#   73.35,
#   'L',
#   58,
#   19),
#  (10318, 'Diego Arroyo', 'Uruguay', '1994', 'SS', 1.93, 77.69, 'L', 63, 19),
#  (10319, 'Hermán Soldano', 'Colombia', '1984', 'CF', 1.67, 61.1, 'R', 58, 19),
#  (10320, 'Miguel Vargas', 'Colombia', '1997', 'SS', 1.93, 62.23, 'L', 65, 19),
#  (10321, 'Rafael Bologna', 'Paraguay', '1996', 'GK', 1.94, 63.25, 'L', 74, 20),
#  (10322,
#   'Teodoro Soldano',
#   'Colombia',
#   '2001',
#   'GK',
#   1.96,
#   86.98,
#   'R',
#   68,
#   20),
#  (10323, 'Deivid Souza', 'Brazil', '1993', 'GK', 1.87, 76.45, 'R', 86, 20),
#  (10324,
#   'Francimar dos Santos',
#   'Brazil',
#   '1997',
#   'LB',
#   1.89,
#   60.6,
#   'L',
#   80,
#   20),
#  (10325,
#   'Teófilo Moreno',
#   'Argentina',
#   '1997',
#   'RB',
#   1.83,
#   85.54,
#   'L',
#   54,
#   20),
#  (10326, 'Lucas Gomez', 'Uruguay', '1992', 'LB', 1.84, 74.59, 'L', 57, 20),
#  (10327,
#   'Patricio Faravelli',
#   'Uruguay',
#   '2002',
#   'LB',
#   1.82,
#   69.11,
#   'L',
#   58,
#   20),
#  (10328, 'Eugenio Vega', 'Paraguay', '1999', 'RB', 1.84, 70.98, 'L', 60, 20),
#  (10329, 'Joan Soldano', 'Argentina', '2006', 'LB', 1.9, 65.15, 'L', 53, 20),
#  (10330,
#   'Miguel di Santoro',
#   'Colombia',
#   '1991',
#   'CB',
#   1.9,
#   81.79,
#   'L',
#   54,
#   20),
#  (10331, 'Guilherme Vivaz', 'Brazil', '1990', 'CB', 1.87, 60.93, 'R', 66, 20),
# ...
#  (10564, 'Mariano Burca', 'Brazil', '1990', 'CB', 1.82, 78.85, 'L', 73, 28),
#  (10565, 'Santiago Luján', 'Chile', '2001', 'RB', 1.86, 61.21, 'L', 89, 28),
#  (10566,
#   'Eugenio Zeballos',
#   'Colombia',
#   '1985',
#   'LB',
#   1.82,
#   87.09,
#   'L',
#   83,
#   28),
#  (10567, 'Juan Pablo Diaz', 'Uruguay', '1991', 'RB', 1.82, 72.63, 'L', 75, 28),
#  (10568, 'Rafael Diaz', 'Uruguay', '1987', 'RB', 1.87, 78.25, 'R', 74, 28),
#  (10569, 'Juan Pavón', 'Colombia', '1989', 'CB', 1.84, 78.99, 'L', 81, 28),
#  (10570, 'Vilmar Rosa', 'Brazil', '1989', 'LB', 1.81, 87.99, 'R', 76, 28),
#  (10571, 'Tomás Álvarez', 'Uruguay', '1985', 'RB', 1.84, 73.74, 'L', 62, 28),
#  (10572, 'José Viña', 'Colombia', '2005', 'RB', 1.88, 73.7, 'R', 52, 28),
#  (10573, 'Angel di Maria', 'Uruguay', '1989', 'LM', 1.89, 81.83, 'R', 86, 28),
#  (10574,
#   'Alejandro Montenegro',
#   'Chile',
#   '1987',
#   'LM',
#   1.69,
#   69.86,
#   'L',
#   61,
#   28),
#  (10575, 'Didiér Gomez', 'Chile', '1996', 'LM', 1.7, 76.68, 'L', 74, 28),
#  (10576,
#   'Rocco Orerruella',
#   'Uruguay',
#   '2006',
#   'LM',
#   1.61,
#   68.42,
#   'R',
#   77,
#   28),
#  (10577, 'Hernán Maduro', 'Paraguay', '1997', 'LM', 1.87, 82.42, 'R', 50, 28),
#  (10578,
#   'Frederico Luján',
#   'Argentina',
#   '1991',
#   'LM',
#   1.65,
#   83.72,
#   'L',
#   86,
#   28),
#  (10579, 'Alfonso Pinos', 'Colombia', '2003', 'DM', 1.65, 67.41, 'R', 50, 28),
#  (10580, 'Rubén Álvarez', 'Argentina', '2002', 'CM', 1.72, 72.06, 'L', 70, 28),
#  (10581, 'Omar Torres', 'Chile', '1984', 'DM', 1.88, 68.16, 'R', 64, 28),
#  (10582,
#   'Benedito dos Santos',
#   'Brazil',
#   '1994',
#   'RM',
#   1.87,
#   67.85,
#   'R',
#   76,
#   28),
#  (10583, 'Franco Zárate', 'Colombia', '2003', 'RM', 1.69, 72.38, 'L', 75, 28),
#  (10584,
#   'Teodoro Guerrero',
#   'Colombia',
#   '1996',
#   'WG',
#   1.73,
#   77.14,
#   'R',
#   69,
#   28),
#  (10585,
#   'Jarrinson Suarez',
#   'Uruguay',
#   '1986',
#   'CF',
#   1.94,
#   86.62,
#   'L',
#   69,
#   28),
#  (10586,
#   'Jarrinson Palavecino',
#   'Argentina',
#   '2006',
#   'WG',
#   1.91,
#   90.82,
#   'R',
#   71,
#   28),
#  (10587, 'Hermán Fontana', 'Chile', '1998', 'CF', 1.7, 90.5, 'L', 70, 28),
#  (10588, 'Maxi Palavecino', 'Chile', '2004', 'SS', 1.8, 69.48, 'R', 85, 28),
#  (10589,
#   'Francisco Hurtado',
#   'Paraguay',
#   '1996',
#   'SS',
#   1.68,
#   88.31,
#   'R',
#   84,
#   28),
#  (10590, 'Carmelo López', 'Chile', '1992', 'CF', 1.62, 83.1, 'R', 61, 28),
#  (10591, 'Andrés Zárate', 'Paraguay', '1997', 'GK', 1.95, 84.53, 'R', 83, 29),
#  (10592, 'Enrique Gomez', 'Colombia', '1992', 'GK', 1.93, 68.71, 'R', 89, 29),
#  (10593,
#   'Emiliano dos Santos',
#   'Uruguay',
#   '1989',
#   'GK',
#   1.88,
#   76.47,
#   'R',
#   86,
#   29),
#  (10594,
#   'Frederico Armani',
#   'Colombia',
#   '2005',
#   'CB',
#   1.85,
#   86.51,
#   'R',
#   58,
#   29),
#  (10595, 'Brayan Garcia', 'Chile', '2000', 'LB', 1.9, 74.1, 'L', 83, 29),
#  (10596, 'Marcio Matheus', 'Brazil', '1997', 'LB', 1.84, 68.29, 'L', 61, 29),
#  (10597, 'Angel Arroyo', 'Colombia', '1987', 'CB', 1.81, 67.43, 'L', 54, 29),
#  (10598, 'Ederson Pacheco', 'Brazil', '1989', 'RB', 1.88, 79.62, 'L', 55, 29),
#  (10599,
#   'Agustin Quintero',
#   'Paraguay',
#   '2003',
#   'RB',
#   1.83,
#   84.06,
#   'R',
#   63,
#   29),
#  (10600, 'Jorge Bologna', 'Colombia', '1994', 'RB', 1.88, 89.88, 'L', 50, 29),
#  (10601, 'Teodoro Murillo', 'Chile', '2005', 'RB', 1.85, 62.78, 'L', 84, 29),
#  (10602,
#   'Lucas De La Muerte',
#   'Argentina',
#   '1998',
#   'RB',
#   1.83,
#   86.44,
#   'L',
#   63,
#   29),
#  (10603,
#   'Francisco Montenegro',
#   'Uruguay',
#   '1992',
#   'DM',
#   1.8,
#   63.13,
#   'L',
#   64,
#   29),
#  (10604,
#   'Hernán Montenegro',
#   'Argentina',
#   '2005',
#   'AM',
#   1.75,
#   87.36,
#   'R',
#   78,
#   29),
#  (10605,
#   'Alejandro del Riego',
#   'Colombia',
#   '1995',
#   'CM',
#   1.72,
#   62.1,
#   'L',
#   70,
#   29),
#  (10606, 'Tomás Chávez', 'Chile', '1986', 'AM', 1.8, 63.62, 'R', 89, 29),
#  (10607, 'Piero Mari', 'Uruguay', '2006', 'DM', 1.69, 73.09, 'L', 64, 29),
#  (10608,
#   'Franco di Santoro',
#   'Argentina',
#   '2002',
#   'RM',
#   1.88,
#   89.82,
#   'R',
#   86,
#   29),
#  (10609,
#   'Jarrinson Cardozo',
#   'Colombia',
#   '1988',
#   'AM',
#   1.65,
#   89.7,
#   'L',
#   61,
#   29),
#  (10610, 'Patrick Branco', 'Brazil', '2005', 'AM', 1.61, 78.21, 'L', 61, 29),
#  (10611,
#   'Juan Camilo Banguero',
#   'Argentina',
#   '1999',
#   'LM',
#   1.65,
#   65.85,
#   'L',
#   51,
#   29),
#  (10612, 'Nicolás Ortiz', 'Uruguay', '1984', 'RM', 1.85, 70.21, 'R', 69, 29),
#  (10613, 'Aldo Ortiz', 'Argentina', '1987', 'AM', 1.71, 83.06, 'R', 78, 29),
#  (10614, 'Diego Salazar', 'Colombia', '1997', 'SS', 1.87, 72.32, 'R', 78, 29),
#  (10615,
#   'Fabián del Riego',
#   'Uruguay',
#   '1987',
#   'CF',
#   1.62,
#   65.98,
#   'R',
#   73,
#   29),
#  (10616,
#   'Teodoro di Santoro',
#   'Colombia',
#   '1986',
#   'WG',
#   1.89,
#   79.62,
#   'R',
#   89,
#   29),
#  (10617, 'Aldo Armani', 'Uruguay', '2003', 'SS', 1.89, 90.47, 'L', 57, 29),
#  (10618, 'Lautaro Arroyo', 'Colombia', '1989', 'SS', 1.81, 65.76, 'R', 51, 29),
#  (10619,
#   'Carlos Victor Eler',
#   'Brazil',
#   '1986',
#   'WG',
#   1.94,
#   61.14,
#   'R',
#   57,
#   29),
#  (10620, 'Ian Palmeiras', 'Brazil', '1986', 'CF', 1.94, 70.85, 'R', 80, 29),
#  (10621, 'Marcos Brandão', 'Brazil', '2005', 'GK', 1.91, 73.92, 'R', 82, 30),
#  (10622, 'Giovani Hurtado', 'Chile', '1996', 'GK', 1.98, 61.57, 'R', 54, 30),
#  (10623, 'Joaquin Plaza', 'Uruguay', '2004', 'GK', 1.93, 86.29, 'R', 68, 30),
#  (10624, 'Enrique Gomez', 'Argentina', '2003', 'LB', 1.81, 83.19, 'L', 86, 30),
#  (10625, 'Alfonso Chávez', 'Chile', '2004', 'RB', 1.81, 80.63, 'R', 87, 30),
#  (10626, 'Enzo Banguero', 'Colombia', '1984', 'LB', 1.88, 80.11, 'L', 85, 30),
#  (10627,
#   'Hernán dos Santos',
#   'Colombia',
#   '1985',
#   'CB',
#   1.81,
#   84.65,
#   'R',
#   90,
#   30),
#  (10628, 'Joaquin Armani', 'Uruguay', '2002', 'RB', 1.88, 86.32, 'L', 54, 30),
#  (10629, 'Agustin Cuellar', 'Chile', '1994', 'RB', 1.84, 63.31, 'L', 62, 30),
#  (10630, 'Diego Mari', 'Argentina', '1992', 'RB', 1.86, 85.02, 'R', 76, 30),
#  (10631,
#   'Rubén Izquierdo',
#   'Colombia',
#   '2006',
#   'LB',
#   1.82,
#   85.98,
#   'R',
#   66,
#   30),
#  (10632, 'Enzo Torres', 'Paraguay', '1989', 'CB', 1.84, 85.92, 'R', 70, 30),
#  (10633, 'Juan Diaz', 'Chile', '1988', 'CM', 1.78, 81.77, 'L', 79, 30),
#  (10634, 'Enzo Montenegro', 'Uruguay', '1995', 'AM', 1.74, 78.76, 'R', 57, 30),
#  (10635, 'Patricio Rojas', 'Uruguay', '1985', 'DM', 1.88, 89.11, 'R', 90, 30),
#  (10636, 'Christian Arias', 'Colombia', '1991', 'LM', 1.67, 66.1, 'L', 77, 30),
#  (10637,
#   'Lautaro Fontana',
#   'Argentina',
#   '1995',
#   'DM',
#   1.86,
#   65.07,
#   'R',
#   73,
#   30),
#  (10638, 'Paolo Mari', 'Argentina', '2001', 'DM', 1.79, 61.11, 'R', 64, 30),
#  (10639, 'Adalto Diniz', 'Brazil', '2001', 'RM', 1.81, 85.02, 'L', 90, 30),
#  (10640, 'Carmelo Arias', 'Uruguay', '1986', 'LM', 1.62, 62.9, 'L', 82, 30),
#  (10641,
#   'Germán Arboleda',
#   'Paraguay',
#   '2005',
#   'CM',
#   1.68,
#   78.78,
#   'R',
#   77,
#   30),
#  (10642, 'Omar Suarez', 'Colombia', '1985', 'RM', 1.68, 60.66, 'L', 66, 30),
#  (10643, 'Javier Vázquez', 'Chile', '2005', 'RM', 1.78, 84.68, 'R', 63, 30),
#  (10644, 'Aldo Soto', 'Argentina', '1998', 'SS', 1.69, 62.45, 'R', 71, 30),
#  (10645, 'Rodrigo Álvarez', 'Uruguay', '1989', 'SS', 1.92, 85.45, 'R', 71, 30),
#  (10646, 'Santiago del Toro', 'Chile', '1994', 'CF', 1.67, 76.34, 'R', 67, 30),
#  (10647, 'Nicolás Arias', 'Colombia', '1989', 'SS', 1.89, 85.07, 'L', 67, 30),
#  (10648,
#   'Estefano Álvarez',
#   'Uruguay',
#   '1985',
#   'CF',
#   1.68,
#   72.95,
#   'R',
#   71,
#   30),
#  (10649, 'Alfonso Arroyo', 'Paraguay', '1998', 'WG', 1.69, 83.59, 'L', 74, 30),
#  (10650,
#   'Alfonso Soldano',
#   'Colombia',
#   '2006',
#   'CF',
#   1.79,
#   65.37,
#   'L',
#   70,
#   30),
#  (10651, 'Jorge Vega', 'Argentina', '2001', 'GK', 1.89, 82.47, 'L', 50, 31),
#  (10652, 'Leandro Rojas', 'Uruguay', '1999', 'GK', 1.93, 86.36, 'R', 80, 31),
#  (10653,
#   'Carlito dos Santos',
#   'Uruguay',
#   '1988',
#   'GK',
#   1.93,
#   67.3,
#   'R',
#   82,
#   31),
#  (10654, 'Edmundo Correia', 'Brazil', '1985', 'CB', 1.89, 79.86, 'R', 68, 31),
#  (10655, 'José Cardozo', 'Paraguay', '1997', 'CB', 1.88, 65.27, 'R', 72, 31),
#  (10656,
#   'Leandrinho Crespo',
#   'Brazil',
#   '1992',
#   'CB',
#   1.82,
#   65.71,
#   'L',
#   70,
#   31),
#  (10657,
#   'Esteban Castillo',
#   'Colombia',
#   '1986',
#   'CB',
#   1.81,
#   60.92,
#   'R',
#   82,
#   31),
#  (10658, 'Antônio Varanda', 'Brazil', '1991', 'CB', 1.8, 71.96, 'R', 73, 31),
#  (10659, 'Miguel Torres', 'Chile', '1999', 'CB', 1.87, 76.77, 'L', 59, 31),
#  (10660, 'Patricio Ortiz', 'Chile', '1994', 'CB', 1.85, 89.7, 'L', 65, 31),
#  (10661, 'Piero Castillo', 'Paraguay', '1998', 'RB', 1.88, 65.88, 'L', 85, 31),
#  (10662, 'Fernando Uribe', 'Paraguay', '1998', 'RB', 1.9, 85.88, 'L', 80, 31),
#  (10663, 'Andrés Valverde', 'Chile', '1988', 'DM', 1.63, 90.24, 'L', 86, 31),
#  (10664,
#   'Guillermo Arboleda',
#   'Argentina',
#   '2001',
#   'AM',
#   1.62,
#   73.24,
#   'L',
#   52,
#   31),
#  (10665, 'Brayan Plaza', 'Chile', '1996', 'CM', 1.77, 89.54, 'L', 56, 31),
#  (10666, 'Brayan Soldano', 'Chile', '1992', 'CM', 1.77, 67.54, 'L', 82, 31),
#  (10667, 'Germán Armani', 'Chile', '1985', 'RM', 1.62, 70.67, 'R', 78, 31),
#  (10668,
#   'Carmelo Arboleda',
#   'Colombia',
#   '1992',
#   'CM',
#   1.69,
#   81.91,
#   'L',
#   71,
#   31),
#  (10669, 'Joan Arroyo', 'Paraguay', '2000', 'RM', 1.65, 78.7, 'R', 76, 31),
#  (10670, 'Hermán Reinoso', 'Colombia', '1991', 'AM', 1.71, 77.19, 'L', 80, 31),
#  (10671, 'Germán Cueva', 'Paraguay', '1995', 'CM', 1.79, 90.31, 'L', 60, 31),
#  (10672,
#   'Nehuén Palavecino',
#   'Uruguay',
#   '1987',
#   'AM',
#   1.7,
#   76.43,
#   'R',
#   88,
#   31),
#  (10673,
#   'Joan De La Cruz',
#   'Argentina',
#   '2003',
#   'AM',
#   1.83,
#   87.62,
#   'L',
#   90,
#   31),
#  (10674, 'Andrés Vargas', 'Uruguay', '1986', 'CF', 1.7, 90.37, 'L', 69, 31),
#  (10675, 'Nehuén dos Santos', 'Chile', '1996', 'SS', 1.94, 80.44, 'R', 66, 31),
#  (10676, 'Iván Cuellar', 'Paraguay', '1988', 'WG', 1.73, 79.28, 'R', 74, 31),
#  (10677, 'Carlito Pinos', 'Argentina', '1998', 'WG', 1.64, 69.69, 'R', 67, 31),
#  (10678, 'Rubén López', 'Argentina', '2006', 'WG', 1.76, 86.48, 'L', 73, 31),
#  (10679,
#   'Giovani Guerrero',
#   'Paraguay',
#   '2005',
#   'WG',
#   1.83,
#   60.2,
#   'R',
#   78,
#   31),
#  (10680,
#   'Jarrinson Martinez',
#   'Uruguay',
#   '1999',
#   'CF',
#   1.75,
#   83.49,
#   'R',
#   58,
#   31),
#  (10681, 'Rocco Soldano', 'Argentina', '1988', 'GK', 1.89, 86.67, 'L', 72, 32),
#  (10682, 'Rocco Viña', 'Chile', '1997', 'GK', 1.92, 63.6, 'R', 58, 32),
#  (10683, 'Maxi dos Santos', 'Chile', '1994', 'GK', 1.91, 68.93, 'R', 87, 32),
#  (10684, 'Marlon Muniz', 'Brazil', '1993', 'LB', 1.84, 61.46, 'R', 53, 32),
#  (10685, 'Stiven Cueva', 'Uruguay', '2001', 'RB', 1.82, 70.68, 'R', 90, 32),
#  (10686,
#   'Patricio Armani',
#   'Argentina',
#   '1998',
#   'LB',
#   1.85,
#   71.63,
#   'L',
#   61,
#   32),
#  (10687, 'Omar Cardozo', 'Paraguay', '2004', 'CB', 1.87, 67.07, 'L', 73, 32),
#  (10688,
#   'Patricio Arroyo',
#   'Paraguay',
#   '1993',
#   'CB',
#   1.83,
#   81.16,
#   'R',
#   80,
#   32),
#  (10689, 'Rocco Giampaolli', 'Chile', '1989', 'LB', 1.81, 73.14, 'R', 85, 32),
#  (10690,
#   'Agustin Arboleda',
#   'Colombia',
#   '1986',
#   'LB',
#   1.89,
#   75.35,
#   'R',
#   59,
#   32),
#  (10691, 'Enzo Jara', 'Paraguay', '1985', 'RB', 1.89, 82.65, 'L', 53, 32),
#  (10692, 'Gustavo Bologna', 'Uruguay', '1995', 'CB', 1.87, 83.21, 'L', 54, 32),
#  (10693,
#   'Patricio di Santoro',
#   'Paraguay',
#   '1988',
#   'AM',
#   1.83,
#   85.31,
#   'L',
#   90,
#   32),
#  (10694, 'Piero Villa', 'Uruguay', '1989', 'LM', 1.89, 62.72, 'L', 67, 32),
#  (10695, 'Andrei Licurgo', 'Brazil', '1987', 'CM', 1.78, 90.12, 'L', 77, 32),
#  (10696,
#   'Estefano Aránguiz',
#   'Uruguay',
#   '2002',
#   'RM',
#   1.71,
#   60.0,
#   'L',
#   55,
#   32),
#  (10697, 'Cezar Silvestre', 'Brazil', '1985', 'RM', 1.8, 85.97, 'L', 74, 32),
#  (10698, 'Jonathan Mica', 'Brazil', '1995', 'CM', 1.65, 65.22, 'R', 80, 32),
#  (10699, 'Jorge Plaza', 'Colombia', '1988', 'AM', 1.72, 76.31, 'L', 79, 32),
#  (10700, 'Gustavo Grilo', 'Brazil', '1986', 'RM', 1.62, 84.83, 'R', 70, 32),
#  (10701, 'Joan Pellerano', 'Chile', '1990', 'CM', 1.68, 78.08, 'L', 84, 32),
#  (10702,
#   'Alfonso Salazar',
#   'Argentina',
#   '1994',
#   'LM',
#   1.8,
#   75.23,
#   'L',
#   57,
#   32),
#  (10703, 'Guido Viña', 'Chile', '1990', 'AM', 1.78, 88.51, 'L', 50, 32),
#  (10704,
#   'Juan Pablo di Santoro',
#   'Argentina',
#   '1987',
#   'WG',
#   1.83,
#   79.33,
#   'L',
#   53,
#   32),
#  (10705, 'Héctor Ortiz', 'Colombia', '1987', 'WG', 1.72, 86.34, 'L', 73, 32),
#  (10706, 'Tuco Guerri', 'Brazil', '1992', 'CF', 1.83, 88.92, 'R', 64, 32),
#  (10707, 'Joaquin Borré', 'Uruguay', '1992', 'SS', 1.88, 61.46, 'L', 55, 32),
#  (10708,
#   'Javier di Santoro',
#   'Uruguay',
#   '2001',
#   'SS',
#   1.91,
#   74.2,
#   'R',
#   57,
#   32),
#  (10709, 'Tomás Maduro', 'Uruguay', '1987', 'CF', 1.64, 60.13, 'R', 77, 32),
#  (10710, 'Estefano Maduro', 'Chile', '1987', 'SS', 1.78, 70.24, 'L', 84, 32),
#  (10711, 'Piero Maduro', 'Argentina', '2003', 'GK', 1.96, 61.79, 'L', 86, 33),
#  (10712, 'Joaquin Mari', 'Chile', '1996', 'GK', 1.92, 87.16, 'R', 80, 33),
#  (10713, 'Rafael Murillo', 'Uruguay', '1992', 'GK', 1.98, 62.1, 'L', 81, 33),
#  (10714, 'Nehuén Soldano', 'Chile', '2005', 'RB', 1.88, 71.7, 'R', 59, 33),
#  (10715,
#   'Fabián de Arrascaeta',
#   'Chile',
#   '1993',
#   'LB',
#   1.9,
#   89.83,
#   'R',
#   73,
#   33),
#  (10716,
#   'Leandro Reinoso',
#   'Colombia',
#   '1995',
#   'RB',
#   1.88,
#   81.68,
#   'R',
#   58,
#   33),
#  (10717, 'Emiliano Isla', 'Paraguay', '1990', 'CB', 1.86, 73.12, 'R', 67, 33),
#  (10718,
#   'Juan Camilo Orerruella',
#   'Uruguay',
#   '1991',
#   'CB',
#   1.81,
#   88.64,
#   'L',
#   74,
#   33),
#  (10719,
#   'Rodrigo Calpado',
#   'Colombia',
#   '2006',
#   'CB',
#   1.82,
#   69.48,
#   'L',
#   81,
#   33),
#  (10720, 'Enzo Álvarez', 'Argentina', '1988', 'RB', 1.84, 60.8, 'L', 69, 33),
#  (10721,
#   'Leandro Bologna',
#   'Argentina',
#   '2001',
#   'CB',
#   1.8,
#   84.28,
#   'L',
#   87,
#   33),
#  (10722, 'Lucas De La Cruz', 'Uruguay', '1995', 'LB', 1.9, 83.55, 'L', 57, 33),
#  (10723, 'Dinho Pera', 'Brazil', '1986', 'LM', 1.9, 82.12, 'R', 83, 33),
#  (10724,
#   'Esteban Sampaoli',
#   'Argentina',
#   '2001',
#   'CM',
#   1.88,
#   82.4,
#   'L',
#   72,
#   33),
#  (10725, 'Tomás Pellerano', 'Colombia', '1993', 'LM', 1.64, 86.5, 'R', 83, 33),
#  (10726,
#   'Emiliano Moreno',
#   'Colombia',
#   '2005',
#   'RM',
#   1.75,
#   84.93,
#   'R',
#   80,
#   33),
#  (10727, 'Fernando Rojas', 'Chile', '2005', 'RM', 1.85, 73.94, 'R', 63, 33),
#  (10728,
#   'Sebastián Arboleda',
#   'Uruguay',
#   '1999',
#   'CM',
#   1.82,
#   76.97,
#   'R',
#   50,
#   33),
#  (10729,
#   'Javier Arrascaita',
#   'Colombia',
#   '1988',
#   'CM',
#   1.89,
#   63.49,
#   'L',
#   65,
#   33),
#  (10730, 'Diego Isla', 'Argentina', '2001', 'RM', 1.66, 83.85, 'L', 74, 33),
#  (10731, 'Aldo Chávez', 'Argentina', '1998', 'AM', 1.72, 61.97, 'L', 60, 33),
#  (10732, 'Marquinho Braga', 'Brazil', '2005', 'AM', 1.81, 78.2, 'R', 50, 33),
#  (10733, 'Maxi Martinez', 'Paraguay', '2000', 'CM', 1.81, 66.32, 'R', 89, 33),
#  (10734,
#   'Frederico Arrascaita',
#   'Colombia',
#   '1989',
#   'SS',
#   1.71,
#   71.83,
#   'L',
#   58,
#   33),
#  (10735,
#   'Estefano Palavecino',
#   'Chile',
#   '1993',
#   'WG',
#   1.71,
#   79.43,
#   'R',
#   67,
#   33),
#  (10736,
#   'Eugenio Zeballos',
#   'Uruguay',
#   '1998',
#   'CF',
#   1.66,
#   81.76,
#   'L',
#   72,
#   33),
#  (10737, 'Juan Arrascaita', 'Uruguay', '2003', 'WG', 1.67, 81.8, 'L', 62, 33),
#  (10738, 'Guido Suarez', 'Argentina', '1998', 'SS', 1.65, 70.6, 'R', 83, 33),
#  (10739,
#   'Gustavo Arroyo',
#   'Argentina',
#   '1996',
#   'CF',
#   1.77,
#   88.05,
#   'R',
#   56,
#   33),
#  (10740,
#   'Enrique di Santoro',
#   'Paraguay',
#   '2006',
#   'CF',
#   1.66,
#   83.11,
#   'L',
#   82,
#   33),
#  (10741, 'Germán Guerrero', 'Uruguay', '1993', 'GK', 1.89, 89.2, 'L', 69, 34),
#  (10742, 'Bento Lopes', 'Brazil', '2002', 'GK', 1.91, 80.04, 'L', 74, 34),
#  (10743,
#   'Nicolás Zeballos',
#   'Uruguay',
#   '1988',
#   'GK',
#   1.91,
#   83.88,
#   'R',
#   82,
#   34),
#  (10744, 'Jorge Hurtado', 'Uruguay', '1993', 'CB', 1.84, 86.68, 'L', 71, 34),
#  (10745, 'Enzo Álvarez', 'Chile', '1997', 'LB', 1.86, 84.25, 'L', 90, 34),
#  (10746, 'Ivan Melo', 'Brazil', '1986', 'LB', 1.84, 63.38, 'L', 83, 34),
#  (10747,
#   'Sebastián Martinez',
#   'Uruguay',
#   '1989',
#   'CB',
#   1.87,
#   64.1,
#   'L',
#   79,
#   34),
#  (10748, 'Gustavo Sampaoli', 'Chile', '2004', 'LB', 1.85, 74.55, 'R', 88, 34),
#  (10749, 'Brayan Borré', 'Uruguay', '1987', 'RB', 1.85, 79.9, 'L', 89, 34),
#  (10750,
#   'Exequiel Giampaolli',
#   'Colombia',
#   '2005',
#   'LB',
#   1.82,
#   66.06,
#   'R',
#   59,
#   34),
#  ...]
