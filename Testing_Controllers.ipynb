# %%
from db.players_controller import PlayersController

# %%
PlayersController().select_players_with_contract('2022')
# Out:
# [(1, 'Neil Muccio', 'Chile', '1993', 'GK', 1.87, 83.51, 'R', 68, 1),
#  (2, 'Casey Niederhaus', 'Paraguay', '1987', 'GK', 1.98, 67.69, 'L', 73, 1),
#  (3, 'Meyer Milad', 'Brazil', '2004', 'GK', 1.89, 74.17, 'R', 67, 1),
#  (4, 'Janet Lenson', 'Colombia', '2002', 'RB', 1.88, 90.43, 'L', 69, 1),
#  (5, 'Brenden Cisne', 'Brazil', '2005', 'RB', 1.88, 85.3, 'L', 65, 1),
#  (6, 'Joschua Lowers', 'Chile', '2004', 'LB', 1.81, 87.14, 'L', 85, 1),
#  (7, 'Chadwick Meyle', 'Brazil', '1984', 'CB', 1.81, 65.24, 'R', 84, 1),
#  (8, 'Conrad Salan', 'Uruguay', '1996', 'RB', 1.88, 89.1, 'L', 70, 1),
#  (9, 'Zane Mcnerny', 'Paraguay', '1999', 'RB', 1.83, 61.56, 'L', 56, 1),
#  (10, 'Dock Go', 'Brazil', '2004', 'RB', 1.84, 77.56, 'R', 78, 1),
#  (11, 'Terry Symank', 'Brazil', '1997', 'LB', 1.86, 78.65, 'R', 56, 1),
#  (12, 'Denis Rauckhorst', 'Uruguay', '1997', 'LB', 1.82, 78.26, 'L', 68, 1),
#  (13, 'Ben Uchima', 'Chile', '1984', 'DM', 1.87, 77.48, 'R', 54, 1),
# ...

# %%
from db.championship_controller import ChampionshipsController

# %%
championship = ChampionshipsController()

# %%
championship.select_championship_table_by_club('2022', 7)
# Out:
# [('Fluminense', 0, 0, 0, 0, 0, 0, 0, 0)]

# %%
championship.select_championship_table_by_division('2022','Serie A')
# Out:
# [('América Mineiro', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Atlético Mineiro', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Athletico Paranaense', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Ceará', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Fortaleza', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Flamengo', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Fluminense', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Cuiabá', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Grêmio', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('International', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Chapecoense', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Juventude', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('São Paulo', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Corinthians', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Palmeiras', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Santos', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Red Bull Bragantino', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Sport Recife', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Bahia', 0, 0, 0, 0, 0, 0, 0, 0),
#  ('Atlético Goianiense', 0, 0, 0, 0, 0, 0, 0, 0)]
