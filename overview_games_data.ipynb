# %%
# Imports 

from helper import ClassConstructor
from db.players_controller import PlayersController
from db.clubs_controller import ClubsController
from db.stadiums_controller import StadiumsController

# %%
# Class declare (statics)

class_const = ClassConstructor()
players_controller = PlayersController()
clubs_controller = ClubsController()
stadiums_controller = StadiumsController()

# %%
# Select and transform stadium data into objects

stadiums_data = stadiums_controller.select_all_stadiums()
stadiums = class_const.stadiums(stadiums_data)

# %%
# Select players with contract

# get from db
p = players_controller.select_players_with_contract('2022') 

# transform into objects
players = class_const.players(p)

# %%
# Serie A clubs selection & cast

serie_a = clubs_controller.select_serie_a_clubs()
serie_a_clubs = class_const.clubs(serie_a)
serie_a_clubs = class_const.add_players_to_clubs(serie_a_clubs, players)

# %%
# Set clubs formation

class_const.define_formation(serie_a_clubs)

# %%
# Define the clubs matches, this will return a list of lists with two differents teams

serie_a_schedule = class_const.define_schedule(serie_a_clubs)

# %%
# Return a list of games object with all the confrontations through the season

serie_a_games = class_const.prepare_games(serie_a_schedule, stadiums, 'Campeonato Brasileiro Serie A', 2022)

# %%
for game in serie_a_games:
    game.start()

# %%
serie_a_games[0]
# Out:
# Game(Club(América Mineiro) x Club(Atlético Mineiro))

# %%
from pprint import pprint

pprint(serie_a_games[0].logs)
# Out:
# {'field': {'audience': 16796,
#            'conditions': {'climate': 'cold',
#                           'hour': '20:00',
#                           'season': 2022,
#                           'weather': 'rainy'},
#            'location': 'None, Brazil',
#            'stadium': 'Zumbi dos Palmares'},
#  'finances': {'audience_full_price': 12919.0,
#               'audience_half_price': 3877.0,
#               'ticket_half_price': 25,
#               'ticket_price': 50},
#  'game_stats': {'América Mineiro': {'ball possession': 0,
#                                     'fouls': 6,
#                                     'free kicks': 0,
#                                     'goals': 2,
#                                     'home': True,
#                                     'interceptions': 0,
#                                     'offsides': 0,
#                                     'passes': 26,
#                                     'penalties': 0,
#                                     'saves': 4,
#                                     'shots': 12,
#                                     'shots on target': 9,
#                                     'stolen_balls': 4,
#                                     'tackles': 6,
#                                     'wrong passes': 4},
#                 'Atlético Mineiro': {'ball possession': 0,
#                                      'fouls': 4,
#                                      'free kicks': 0,
#                                      'goals': 3,
#                                      'home': True,
#                                      'interceptions': 3,
#                                      'offsides': 0,
#                                      'passes': 24,
#                                      'penalties': 0,
#                                      'saves': 7,
#                                      'shots': 13,
#                                      'shots on target': 7,
#                                      'stolen_balls': 4,
#                                      'tackles': 6,
#                                      'wrong passes': 7}},
#  'others': {'away_goals': 3,
#             'draw': False,
#             'home_goals': 2,
#             'loser': 'América Mineiro',
#             'winner': 'Atlético Mineiro'},
#  'player_stats': {'assists': defaultdict(<class 'int'>,
#                                          {Player(Epíteto Mendes): 1}),
#                   'clearances': defaultdict(<class 'int'>, {}),
#                   'defenses': defaultdict(<class 'int'>,
#                                           {Player(Cauã Eler): 4,
#                                            Player(Abstêmio Alcantara): 7}),
#                   'dificult_defenses': defaultdict(<class 'int'>, {}),
#                   'fouls': defaultdict(<class 'int'>,
#                                        {Player(Alfonso Garcialopez): 2,
#                                         Player(Lóris Alvarenga): 2,
#                                         Player(Epíteto Mendes): 2,
#                                         Player(Fernão Gonçalves): 1,
#                                         Player(Ronny Betti): 3}),
#                   'goals': defaultdict(<class 'int'>,
#                                        {Player(Alfonso Garcialopez): 1,
#                                         Player(Lóris Alvarenga): 1,
#                                         Player(Abstêmio Alcantara): 1,
#                                         Player(Epíteto Mendes): 1,
#                                         Player(Palemon Burca): 1}),
#                   'intercepted_passes': defaultdict(<class 'int'>,
#                                                     {Player(Fernão Gonçalves): 1,
#                                                      Player(Ronny Betti): 2}),
#                   'passes': defaultdict(<class 'int'>,
#                                         {Player(Cauã Eler): 11,
#                                          Player(Megaron Celso): 1,
#                                          Player(Jaime Guerri): 1,
#                                          Player(Alfonso Garcialopez): 5,
#                                          Player(Lóris Alvarenga): 3,
#                                          Player(Sherlock Falcao): 5,
#                                          Player(Abstêmio Alcantara): 12,
#                                          Player(Epíteto Mendes): 2,
#                                          Player(Fernão Gonçalves): 5,
#                                          Player(Palemon Burca): 2,
#                                          Player(Ronny Betti): 3}),
#                   'stolen_balls': defaultdict(<class 'int'>,
#                                               {Player(Jaime Guerri): 1,
#                                                Player(Lóris Alvarenga): 1,
#                                                Player(Sherlock Falcao): 2,
#                                                Player(Epíteto Mendes): 1,
#                                                Player(Fernão Gonçalves): 2,
#                                                Player(Palemon Burca): 1}),
#                   'tackles': defaultdict(<class 'int'>,
#                                          {Player(Jaime Guerri): 1,
#                                           Player(Alfonso Garcialopez): 4,
#                                           Player(Lóris Alvarenga): 1,
#                                           Player(Epíteto Mendes): 1,
#                                           Player(Fernão Gonçalves): 2,
#                                           Player(Palemon Burca): 1,
#                                           Player(Héctor Misquez): 1,
#                                           Player(Ronny Betti): 1}),
#                   'wrong_passes': defaultdict(<class 'int'>,
#                                               {Player(Cauã Eler): 1,
#                                                Player(Alfonso Garcialopez): 2,
#                                                Player(Lóris Alvarenga): 1,
#                                                Player(Abstêmio Alcantara): 2,
#                                                Player(Epíteto Mendes): 1,
#                                                Player(Fernão Gonçalves): 3,
#                                                Player(Palemon Burca): 1})},
#  'players': {'away': [Player(Abstêmio Alcantara),
#                       Player(Téo Fiuza),
#                       Player(Alfonso Guitierez),
#                       Player(Imael Vieira),
#                       Player(Agnato Reis),
#                       Player(Paranaguá Dias),
#                       Player(Rosário Fiuza),
#                       Player(Epíteto Mendes),
#                       Player(Ronny Betti),
#                       Player(Araípe Vivaz),
#                       Player(Fernão Gonçalves),
#                       Player(Piero Gongalez),
#                       Player(Teófilo Miranda),
#                       Player(Adelmo de Camargo),
#                       Player(Palemon Burca),
#                       Player(Héctor Misquez)],
#              'home': [Player(Cauã Eler),
#                       Player(Beoto Souza),
#                       Player(Rocco Terriquez),
#                       Player(Eco Braga),
#                       Player(Acir Vivaz),
#                       Player(Jaime Guerri),
#                       Player(Tapiraça Veles),
#                       Player(Waclaw Araujo),
#                       Player(Yure Cella),
#                       Player(Lóris Alvarenga),
#                       Player(Sherlock Falcao),
#                       Player(Alfonso Garcialopez),
#                       Player(Estéfano Valadares),
#                       Player(Drímaco Carmona),
#                       Player(Megaron Celso),
#                       Player(Garibaldi Mendes)]},
#  'scoreboard': '2 x 3'}

# %%
pprint(serie_a_games[1].logs)
# Out:
# {'field': {'audience': 37689,
#            'conditions': {'climate': 'cold',
#                           'hour': '22:00',
#                           'season': 2022,
#                           'weather': 'sunny'},
#            'location': 'Belo Horizonte, Brazil',
#            'stadium': 'Mineirão'},
#  'finances': {'audience_full_price': 28991.0,
#               'audience_half_price': 8698.0,
#               'ticket_half_price': 25,
#               'ticket_price': 50},
#  'game_stats': {'América Mineiro': {'ball possession': 0,
#                                     'fouls': 9,
#                                     'free kicks': 0,
#                                     'goals': 3,
#                                     'home': True,
#                                     'interceptions': 4,
#                                     'offsides': 0,
#                                     'passes': 29,
#                                     'penalties': 0,
#                                     'saves': 2,
#                                     'shots': 9,
#                                     'shots on target': 7,
#                                     'stolen_balls': 4,
#                                     'tackles': 4,
#                                     'wrong passes': 5},
#                 'Athletico Paranaense': {'ball possession': 0,
#                                          'fouls': 9,
#                                          'free kicks': 0,
#                                          'goals': 6,
#                                          'home': True,
#                                          'interceptions': 7,
#                                          'offsides': 0,
#                                          'passes': 30,
#                                          'penalties': 0,
#                                          'saves': 4,
#                                          'shots': 8,
#                                          'shots on target': 8,
#                                          'stolen_balls': 9,
#                                          'tackles': 6,
#                                          'wrong passes': 14}},
#  'others': {'away_goals': 6,
#             'draw': False,
#             'home_goals': 3,
#             'loser': 'América Mineiro',
#             'winner': 'Athletico Paranaense'},
#  'player_stats': {'assists': defaultdict(<class 'int'>,
#                                          {Player(Drímaco Carmona): 1,
#                                           Player(Javan Becker): 1,
#                                           Player(Damon Bacci): 1}),
#                   'clearances': defaultdict(<class 'int'>, {}),
#                   'defenses': defaultdict(<class 'int'>,
#                                           {Player(Cauã Eler): 2,
#                                            Player(Urbanus Costa): 4}),
#                   'dificult_defenses': defaultdict(<class 'int'>, {}),
#                   'fouls': defaultdict(<class 'int'>,
#                                        {Player(Megaron Celso): 1,
#                                         Player(Jaime Guerri): 3,
#                                         Player(Drímaco Carmona): 2,
#                                         Player(Lóris Alvarenga): 2,
#                                         Player(Sherlock Falcao): 1,
#                                         Player(Moacir Vivaz): 2,
#                                         Player(Piero Hernandez): 1,
#                                         Player(James Padrão): 1,
#                                         Player(Bispo dos Santos): 3,
#                                         Player(Bonjy Livio): 2}),
#                   'goals': defaultdict(<class 'int'>,
#                                        {Player(Megaron Celso): 2,
#                                         Player(Sherlock Falcao): 1,
#                                         Player(Urbanus Costa): 2,
#                                         Player(Moacir Vivaz): 2,
#                                         Player(Javan Becker): 1,
#                                         Player(Damon Bacci): 1}),
#                   'intercepted_passes': defaultdict(<class 'int'>,
#                                                     {Player(Jaime Guerri): 2,
#                                                      Player(Lóris Alvarenga): 1,
#                                                      Player(Sherlock Falcao): 1,
#                                                      Player(Moacir Vivaz): 2,
#                                                      Player(James Padrão): 1,
#                                                      Player(Bispo dos Santos): 3,
#                                                      Player(Bonjy Livio): 1}),
#                   'passes': defaultdict(<class 'int'>,
#                                         {Player(Cauã Eler): 7,
#                                          Player(Megaron Celso): 1,
#                                          Player(Jaime Guerri): 6,
#                                          Player(Alfonso Garcialopez): 1,
#                                          Player(Drímaco Carmona): 1,
#                                          Player(Lóris Alvarenga): 8,
#                                          Player(Sherlock Falcao): 5,
#                                          Player(Urbanus Costa): 8,
#                                          Player(Moacir Vivaz): 4,
#                                          Player(Javan Becker): 4,
#                                          Player(Piero Hernandez): 3,
#                                          Player(James Padrão): 2,
#                                          Player(Bispo dos Santos): 3,
#                                          Player(Bonjy Livio): 6}),
#                   'stolen_balls': defaultdict(<class 'int'>,
#                                               {Player(Icrá Alcantara): 1,
#                                                Player(Megaron Celso): 1,
#                                                Player(Lóris Alvarenga): 1,
#                                                Player(Sherlock Falcao): 1,
#                                                Player(Moacir Vivaz): 3,
#                                                Player(Javan Becker): 2,
#                                                Player(Piero Hernandez): 1,
#                                                Player(Damon Bacci): 1,
#                                                Player(Bispo dos Santos): 1,
#                                                Player(Bonjy Livio): 1}),
#                   'tackles': defaultdict(<class 'int'>,
#                                          {Player(Jaime Guerri): 2,
#                                           Player(Lóris Alvarenga): 2,
#                                           Player(Moacir Vivaz): 2,
#                                           Player(Javan Becker): 1,
#                                           Player(Piero Hernandez): 2,
#                                           Player(James Padrão): 1}),
#                   'wrong_passes': defaultdict(<class 'int'>,
#                                               {Player(Cauã Eler): 2,
#                                                Player(Lóris Alvarenga): 1,
#                                                Player(Sherlock Falcao): 2,
#                                                Player(Urbanus Costa): 4,
#                                                Player(Moacir Vivaz): 2,
#                                                Player(Javan Becker): 2,
#                                                Player(James Padrão): 1,
#                                                Player(Bispo dos Santos): 2,
#                                                Player(Bonjy Livio): 3})},
#  'players': {'away': [Player(Urbanus Costa),
#                       Player(Mêncio Paes),
#                       Player(Elmar Varanda),
#                       Player(Perato Valadares),
#                       Player(Acelino Betin),
#                       Player(Piero Hernandez),
#                       Player(Javan Becker),
#                       Player(Damon Bacci),
#                       Player(James Padrão),
#                       Player(Bonjy Livio),
#                       Player(Jácomo Lemos),
#                       Player(Menotti Laranjeira),
#                       Player(Bispo dos Santos),
#                       Player(Lucas Gonez),
#                       Player(Hermán Rojas),
#                       Player(Moacir Vivaz)],
#              'home': [Player(Cauã Eler),
#                       Player(Beoto Souza),
#                       Player(Rocco Terriquez),
#                       Player(Eco Braga),
#                       Player(Acir Vivaz),
#                       Player(Jaime Guerri),
#                       Player(Tapiraça Veles),
#                       Player(Waclaw Araujo),
#                       Player(Yure Cella),
#                       Player(Lóris Alvarenga),
#                       Player(Sherlock Falcao),
#                       Player(José Alirez),
#                       Player(Céu Valadares),
#                       Player(Davidson Nunes),
#                       Player(Icrá Alcantara),
#                       Player(Alcídes Laranja)]},
#  'scoreboard': '3 x 6'}

# %%
serie_a_games[2].logs
# Out:
# {'game_stats': {'América Mineiro': {'home': True,
#    'goals': 3,
#    'shots': 7,
#    'shots on target': 8,
#    'fouls': 10,
#    'passes': 31,
#    'wrong passes': 11,
#    'interceptions': 3,
#    'tackles': 9,
#    'stolen_balls': 5,
#    'saves': 4,
#    'ball possession': 0,
#    'offsides': 0,
#    'free kicks': 0,
#    'penalties': 0},
#   'Ceará': {'home': True,
#    'goals': 5,
#    'shots': 10,
#    'shots on target': 9,
#    'fouls': 8,
#    'passes': 26,
#    'wrong passes': 4,
#    'interceptions': 4,
#    'tackles': 8,
#    'stolen_balls': 3,
#    'saves': 5,
#    'ball possession': 0,
#    'offsides': 0,
#    'free kicks': 0,
#    'penalties': 0}},
#  'scoreboard': '3 x 5',
#  'player_stats': {'assists': defaultdict(int,
#               {Player(Francisco Vaidez): 1, Player(Megaron Celso): 1}),
#   'goals': defaultdict(int,
#               {Player(Germano Grilo): 1,
#                Player(Lóris Alvarenga): 1,
#                Player(Rodrigo Goez): 3,
#                Player(Adolphus Mica): 1,
#                Player(Icrá Alcantara): 1,
#                Player(Brayan Cardinez): 1}),
#   'tackles': defaultdict(int,
#               {Player(Patricio Villagomez): 2,
#                Player(Céu Valadares): 2,
#                Player(Seiji Mello): 1,
#                Player(Rodrigo Goez): 3,
#                Player(Jaime Guerri): 2,
#                Player(Icrá Alcantara): 1,
#                Player(Carmelo Chiprez): 2,
#                Player(Brayan Cardinez): 3,
#                Player(Sherlock Falcao): 1}),
#   'defenses': defaultdict(int,
#               {Player(Cauã Eler): 4, Player(Germano Grilo): 5}),
#   'passes': defaultdict(int,
#               {Player(Davidson Nunes): 1,
#                Player(Cauã Eler): 9,
#                Player(Patricio Villagomez): 4,
#                Player(Sherlock Falcao): 5,
#                Player(Xenofonte Menezes): 1,
#                Player(Lóris Alvarenga): 1,
#                Player(Adelelmo Fernandes): 1,
#                Player(Germano Grilo): 8,
#                Player(Céu Valadares): 3,
#                Player(Rodrigo Goez): 2,
#                Player(Joatã Santos): 1,
#                Player(Adolphus Mica): 1,
#                Player(Brayan Cardinez): 6,
#                Player(Francisco Vaidez): 3,
#                Player(Carmelo Chiprez): 5,
#                Player(Megaron Celso): 1,
#                Player(Seiji Mello): 1,
#                Player(Jaime Guerri): 1,
#                Player(Icrá Alcantara): 3}),
#   'wrong_passes': defaultdict(int,
#               {Player(Davidson Nunes): 1,
#                Player(Lóris Alvarenga): 1,
#                Player(Adelelmo Fernandes): 1,
#                Player(Germano Grilo): 1,
#                Player(Céu Valadares): 2,
#                Player(Cauã Eler): 2,
#                Player(Joatã Santos): 1,
#                Player(Brayan Cardinez): 2,
#                Player(Carmelo Chiprez): 1,
#                Player(Megaron Celso): 1,
#                Player(Seiji Mello): 1,
#                Player(Icrá Alcantara): 1}),
#   'intercepted_passes': defaultdict(int,
#               {Player(Lóris Alvarenga): 1,
#                Player(Sherlock Falcao): 1,
#                Player(Carmelo Chiprez): 2,
#                Player(Icrá Alcantara): 1,
#                Player(Patricio Villagomez): 1,
#                Player(Seiji Mello): 1}),
#   'dificult_defenses': defaultdict(int, {}),
#   'clearances': defaultdict(int, {}),
#   'fouls': defaultdict(int,
#               {Player(Adolphus Mica): 2,
#                Player(Lóris Alvarenga): 3,
#                Player(Adelelmo Fernandes): 1,
#                Player(Patricio Villagomez): 1,
#                Player(Sherlock Falcao): 2,
#                Player(Joatã Santos): 1,
#                Player(Francisco Vaidez): 2,
#                Player(Jaime Guerri): 1,
#                Player(Carmelo Chiprez): 3,
#                Player(Icrá Alcantara): 1,
#                Player(Seiji Mello): 1}),
#   'stolen_balls': defaultdict(int,
#               {Player(Patricio Villagomez): 1,
#                Player(Sherlock Falcao): 2,
#                Player(Xenofonte Menezes): 1,
#                Player(Icrá Alcantara): 3,
#                Player(Seiji Mello): 1})},
#  'players': {'home': [Player(Cauã Eler),
#    Player(Beoto Souza),
#    Player(Rocco Terriquez),
#    Player(Eco Braga),
#    Player(Acir Vivaz),
#    Player(Jaime Guerri),
#    Player(Tapiraça Veles),
#    Player(Waclaw Araujo),
#    Player(Yure Cella),
#    Player(Lóris Alvarenga),
#    Player(Sherlock Falcao),
#    Player(Juan Pablo Papez),
#    Player(Brayan Cardinez),
#    Player(Joatã Santos),
#    Player(Athos Guerri),
#    Player(Kriger Alvarenga)],
#   'away': [Player(Germano Grilo),
#    Player(Cândole Carvalho),
#    Player(Christian Belmontez),
#    Player(Pirajá Rainha),
#    Player(Roquete Teles),
#    Player(Diaurum Diaz),
#    Player(Francisco Vaidez),
#    Player(Adolphus Mica),
#    Player(Adelelmo Fernandes),
#    Player(Xenofonte Menezes),
#    Player(Patricio Villagomez),
#    Player(Rodrigo Goez),
#    Player(Carmelo Chiprez),
#    Player(Seiji Mello),
#    Player(Uahoomanaokahaku Militão),
#    Player(Rafael Arias)]},
#  'others': {'winner': 'Ceará',
#   'loser': 'América Mineiro',
#   'draw': False,
#   'home_goals': 3,
#   'away_goals': 5},
#  'field': {'location': 'None, Brazil',
#   'stadium': 'Estádio Porto Alegre',
#   'audience': 24003,
#   'conditions': {'season': 2022,
#    'climate': 'cold',
#    'weather': 'cloudless',
#    'hour': '11:00'}},
#  'finances': {'ticket_price': 50,
#   'ticket_half_price': 25,
#   'audience_full_price': 18463.0,
#   'audience_half_price': 5540.0}}
